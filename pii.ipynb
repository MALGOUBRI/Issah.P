# %% [markdown]
# <a href="https://colab.research.google.com/github/MALGOUBRI/Issah.P/blob/main/pii.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **BERT & Regular Expression–Based PII Detection in MIMIC-III Notes**
# _Comprehensive pipeline integrating weak supervision, clustering, and transformer-based NER._

# %% [markdown]
# ## **1. Library Imports and Environment Setup**
# Import required packages, set random seeds, and configure environment paths.

# %%
# 1) Imports libraries
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.metrics import silhouette_score, davies_bouldin_score, precision_score, recall_score, f1_score
import torch; torch.cuda.is_available()
from sklearn.cluster import KMeans, DBSCAN

# %% [markdown]
# ## **2. Authentication and BigQuery Connection**
# Authenticate user session and create a BigQuery client for dataset access.

# %% [markdown]
# Sample sizes and model refinement(summary interpretation of model performance scalability based on sample size)
# The original analysis pulled 5,000 notes (≈0.24% of the corpus) for pilot runs.
# For refinement, the pull was expanded to 10,000 notes.
# When scaling from 5,000 → 10,000:
# • Precision fell (0.950 → 0.854, Δ = –0.096)
# • Recall rose (0.486 → 0.580, Δ = +0.094)
# • F1 rose (0.643 → 0.691, Δ = +0.048)
# • DBSCAN Silhouette dropped (0.385 → 0.225), DBI rose (0.924 → 1.276)
# DBSCAN remained the best overall relative to K-Means and Hierarchical.
# This code defaults to 5,000, but the LIMIT can be changed to 10,000
# (or other values) during review and comparison as needed.
# While this section focuses on clustering scalability, the BERT-based NER module was used separately to validate and interpret PII-rich clusters, confirming that clusters with high weak-label density often corresponded to notes containing identifiable entities

# %%
# --- Count total notes and compute the % that 5,000 represents ---

# Authenticate (Colab)
from google.colab import auth
auth.authenticate_user()

from google.cloud import bigquery

# BigQuery client (use your project and US location, per PhysioNet datasets)
client = bigquery.Client(project="global-tine-449221-p8", location="US")

# Correct table for NOTEEVENTS (PhysioNet)
table_fq = "physionet-data.mimiciii_notes.noteevents"

# Query total note count
query_total = f"SELECT COUNT(1) AS total_n FROM `{table_fq}`"
total_result = client.query(query_total).result()
total_n = next(total_result).total_n

# Your analysis sample size
sample_n = 5_000  # adjust if your working subset changes

# Compute and report
pct = (sample_n / total_n) * 100.0

print(f"Corpus total (noteevents): {total_n:,}")
print(f"Sample size: {sample_n:,}")
print(f"Sample as percent of corpus: {pct:.4f}%")
# Out:
# Corpus total (noteevents): 2,083,180
# Sample size: 5,000
# Sample as percent of corpus: 0.2400%

# %% [markdown]
# ## **3. Load MIMIC-III Noteevents Sample**
# Query and load a representative 5 000-note subset for experimentation.

# %% [markdown]
# This step applies weak supervision through rule-based regex proxies to generate binary proxy labels (PII present vs. absent). These labels provide an approximate ground truth for evaluating clustering and can also be used to bootstrap machine learning models.### Short Note — Data Integration and Proxy Labels
#
# The data integration step creates a single analytic table by merging the BigQuery extract of MIMIC-III notes with a binary indicator of potential PII. After loading `notes_df` (with identifiers, demographics, timestamps, and free text), the pipeline compiles regular expressions for common PII surface forms—MIMIC redaction placeholders `[**…**]`, Social Security numbers, telephone numbers, email addresses, address-like strings, and ZIP codes—and applies them to `TEXT`. The result, `proxy_pii ∈ {0,1}`, is appended as a new column (and optionally exported as the vector `y_true`). These **proxy labels** are rule-derived, weak indicators that a note contains content likely to be PII; they are **not** ground truth annotations. In this study they serve only to (a) validate the unsupervised clustering outputs via precision/recall/F1 and (b) calibrate thresholds, thereby linking the clustering stage to privacy-aware evaluation without requiring manual labeling.

# %%
 # Load MIMIC Dataset notes (BigQuery)

from google.colab import auth; auth.authenticate_user()
from google.cloud import bigquery
client = bigquery.Client(project="global-tine-449221-p8")
try:
    notes_df = client.query("""
    SELECT n.ROW_ID, n.TEXT
    FROM `physionet-data.mimiciii_notes.noteevents` n
    LIMIT 5000
    """).to_dataframe()
except Exception:
    raise RuntimeError("Provide a DataFrame `notes_df` with a 'TEXT' column or enable BigQuery access.")
notes_df = notes_df.dropna(subset=["TEXT"]).reset_index(drop=True)

# %% [markdown]
# ## **4. Exploratory Data Analysis – Text Length Distribution**
# Visualize the distribution of clinical note lengths (character count histogram).

# %%
# === Miscellaneous: Distribution of Notes Lengths (Characters) ===
import numpy as np
import matplotlib.pyplot as plt

# Character counts per note
lengths = notes_df["TEXT"].astype(str).str.len()
lengths = lengths[lengths > 0]

# Log-spaced bins for a log-scale x-axis
bins = np.logspace(np.log10(lengths.min()), np.log10(lengths.max()), 40)

plt.figure(figsize=(8,5))
plt.hist(lengths, bins=bins)
plt.title("Distribution of Notes Lengths (Characters)")
plt.xlabel("Note length (characters, log scale)")
plt.ylabel("Frequency")
plt.xscale("log")
plt.tight_layout()
plt.show()
# Optional: save for your dissertation
# plt.savefig("notes_length_hist.png", dpi=300, bbox_inches="tight")

# %% [markdown]
# ## **5. Descriptive Statistics of Note Lengths**
# Display five-number summary and standard deviation of note lengths.

# %%
import pandas as pd

# Length features
chars = notes_df["TEXT"].astype(str).str.len()
words = notes_df["TEXT"].astype(str).str.split().str.len()

def summarize(s: pd.Series) -> pd.Series:
    return pd.Series({
        "min":    float(s.min()),
        "q1":     float(s.quantile(0.25)),
        "median": float(s.median()),
        "q3":     float(s.quantile(0.75)),
        "max":    float(s.max()),
        "std":    float(s.std(ddof=1)),   # sample SD
    })

summary = pd.concat(
    [summarize(chars), summarize(words)],
    axis=1
)
summary.columns = ["chars", "words"]
summary = summary.loc[["min", "q1", "median", "q3", "max", "std"]].round(2)

# Display (Colab/Jupyter)
from IPython.display import display
display(summary.style.set_caption("Five-number summary (+ SD):"))
# Plain-text alternative:
# print(summary.to_string())
# Out:
# <style type="text/css">
# </style>
# <table id="T_a1a8b" class="dataframe">
#   <caption>Five-number summary (+ SD):</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1a8b_level0_col0" class="col_heading level0 col0" >chars</th>
#       <th id="T_a1a8b_level0_col1" class="col_heading level0 col1" >words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1a8b_level0_row0" class="row_heading level0 row0" >min</th>
#       <td id="T_a1a8b_row0_col0" class="data row0 col0" >3.000000</td>
#       <td id="T_a1a8b_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a1a8b_level0_row1" class="row_heading level0 row1" >q1</th>
#       <td id="T_a1a8b_row1_col0" class="data row1 col0" >165.000000</td>
#       <td id="T_a1a8b_row1_col1" class="data row1 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a1a8b_level0_row2" class="row_heading level0 row2" >median</th>
#       <td id="T_a1a8b_row2_col0" class="data row2 col0" >271.000000</td>
#       <td id="T_a1a8b_row2_col1" class="data row2 col1" >37.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a1a8b_level0_row3" class="row_heading level0 row3" >q3</th>
#       <td id="T_a1a8b_row3_col0" class="data row3 col0" >2399.500000</td>
#       <td id="T_a1a8b_row3_col1" class="data row3 col1" >336.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a1a8b_level0_row4" class="row_heading level0 row4" >max</th>
#       <td id="T_a1a8b_row4_col0" class="data row4 col0" >46786.000000</td>
#       <td id="T_a1a8b_row4_col1" class="data row4 col1" >6680.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a1a8b_level0_row5" class="row_heading level0 row5" >std</th>
#       <td id="T_a1a8b_row5_col0" class="data row5 col0" >4603.120000</td>
#       <td id="T_a1a8b_row5_col1" class="data row5 col1" >687.820000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **6. Regex-Based Weak Labeling for PII Detection and Interpretation**
# Define regex patterns (emails, SSNs, phones, addresses) and produce weak labels `y_true`.

# %% [markdown]
# This step applies weak supervision through rule-based regular expression (regex) proxies to generate binary proxy labels (PII present vs. absent). These labels provide an approximate ground truth for evaluating clustering and can also be used to bootstrap machine learning models in this case BERT (Bidirectional Encoder Representaions from Transformers) .
#
# The data integration step creates a single analytic table by merging the BigQuery extract of MIMIC-III notes with a binary indicator of potential PII. After loading `notes_df` (with identifiers, demographics, timestamps, and free text), the pipeline compiles regular expressions for common PII surface forms—MIMIC redaction placeholders `[**…**]`, Social Security numbers, telephone numbers, email addresses, address-like strings, and ZIP codes—and applies them to `TEXT`. The result, `proxy_pii ∈ {0,1}`, is appended as a new column (and optionally exported as the vector `y_true`). These **proxy labels** are rule-derived, weak indicators that a note contains content likely to be PII; they are **not** ground truth annotations. In this study they serve only to (a) validate the unsupervised clustering outputs via precision/recall/F1 and (b) calibrate thresholds, thereby linking the clustering stage to privacy-aware evaluation without requiring manual labeling.
#
# “1” means that note matched at least one regex proxy for PII.
# In the array, every element is 1, so every sampled note contains at least one proxy match (e.g., an email, phone, ZIP, SSN format, address-like string, or a MIMIC redaction placeholder such as [** ... **]).
#
# Clarifications:
#
# These are proxy matches, not verified ground truth. They can include MIMIC redaction markers (which indicate where PHI originally was) and may yield false positives/negatives.
#
# An all-ones vector often occurs because the placeholder pattern \[ \*\* .*? \*\* \] is frequent in MIMIC notes.

# %%
# Weak labels (proxy PII) – MIMIC placeholders + common PHI regexes
PII_PATTERNS = [
    r"\[\*\*.*?\*\*\]",  # MIMIC redaction placeholders (proxy for PHI locations)
    r"\b\d{3}-\d{2}-\d{4}\b",  # SSN
    r"\b(?:\+?1[\s.-]?)?(?:\(\d{3}\)|\d{3})[\s.-]?\d{3}[\s.-]?\d{4}\b",  # phone
    r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b",  # email
    r"\b\d{1,5}\s+[A-Za-z0-9.\- ]+\s+(?:St|Street|Ave|Avenue|Rd|Road|Blvd|Lane|Ln|Dr|Drive)\b",  # address-ish
    r"\b\d{5}(?:-\d{4})?\b"  # ZIP
]
rx = re.compile("|".join(PII_PATTERNS))
y_true = notes_df["TEXT"].str.contains(rx).astype(int).to_numpy()  # 1 if any proxy PII pattern, else 0

y_true
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# ## **7. Feature Engineering and Dimensionality Reduction**
# Convert text to TF-IDF vectors, apply Truncated SVD, and normalize for clustering.

# %% [markdown]
# Step and Purpose
#
# Step: Feature engineering and unsupervised clustering with model selection.
# Purpose: Convert text to vectors, compress to a compact space, normalize, then run DBSCAN over a small grid of eps values and pick the setting that yields the best clustering quality (high silhouette, low Davies–Bouldin).
# Note that DBSCAN is chosen insted of KMeans and Hierarchical clustering , beacuse DBSCAN comes with high silhouette, low Davies–Bouldin(DBSCAN: silhouette ≈ 0.445, DBI ≈ 0.994
#
# K-Means: silhouette ≈ 0.189, DBI ≈ 2.641. See below for K-Means result.
# Hierarchical: silhouette ≈ 0.204, DBI ≈ 1.472. See below for K-Means and Hierarchical  result

# %%
# Features: TF-IDF -> SVD(100) -> L2 normalize  (compact, robust for DBSCAN)
X_tfidf = TfidfVectorizer(stop_words="english", max_features=3000).fit_transform(notes_df["TEXT"])
X = normalize(TruncatedSVD(n_components=100, random_state=42).fit_transform(X_tfidf))

# DBSCAN (choose eps by small grid on silhouette; noise (-1) excluded for scoring)
def fit_dbscan(eps):
    lab = DBSCAN(eps=eps, min_samples=5, metric="euclidean").fit_predict(X)
    valid = lab != -1
    if valid.sum() > 1 and len(np.unique(lab[valid])) > 1:
        sil = silhouette_score(X[valid], lab[valid])
        dbi = davies_bouldin_score(X[valid], lab[valid])
    else:
        sil, dbi = np.nan, np.nan
    return lab, sil, dbi

candidates = [0.5, 0.7, 0.9]
best = max((fit_dbscan(eps) + (eps,) for eps in candidates),
           key=lambda t: (np.nan_to_num(t[1], nan=-1), -np.nan_to_num(t[2], nan=np.inf)))
labels, sil, dbi, best_eps = best

# %% [markdown]
# ## **8. Variance Explained by Truncated SVD**
# Plot scree and cumulative variance curves to select optimal dimensionality.

# %%
# --- Scree plot for Truncated SVD on TF–IDF features ---
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD

# Assumptions:
# - You already created X_tfidf with TfidfVectorizer on notes_df["TEXT"]
#   e.g., X_tfidf = TfidfVectorizer(stop_words="english", max_features=3000).fit_transform(notes_df["TEXT"])

# 1) Fit SVD with a sufficiently large cap (e.g., 200) to visualize the elbow
n_components_scree = 200
svd_scree = TruncatedSVD(n_components=n_components_scree, random_state=42)
svd_scree.fit(X_tfidf)

explained = svd_scree.explained_variance_ratio_
cum_explained = np.cumsum(explained)

# 2) Report how many components reach common thresholds
for thr in (0.80, 0.90, 0.95):
    k = int(np.searchsorted(cum_explained, thr) + 1)
    print(f"Components needed to reach {int(thr*100)}% variance: {k}")

# 3) Plot: per-component (scree) + cumulative explained variance
plt.figure(figsize=(8,5))
plt.plot(np.arange(1, len(explained)+1), explained, marker='o', linewidth=1)
plt.xlabel("Component index")
plt.ylabel("Explained variance ratio")
plt.title("Scree plot: Truncated SVD on TF–IDF")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("svd_scree_plot.png", dpi=300, bbox_inches="tight")
plt.show()

plt.figure(figsize=(8,5))
plt.plot(np.arange(1, len(cum_explained)+1), cum_explained, marker='o', linewidth=1)
plt.axhline(0.80, color='gray', linestyle='--', linewidth=1)
plt.axhline(0.90, color='gray', linestyle='--', linewidth=1)
plt.axhline(0.95, color='gray', linestyle='--', linewidth=1)
plt.xlabel("Component index")
plt.ylabel("Cumulative explained variance")
plt.title("Cumulative explained variance: Truncated SVD on TF–IDF")
plt.ylim(0, 1.01)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("svd_cumulative_explained.png", dpi=300, bbox_inches="tight")
# Out:
# Components needed to reach 80% variance: 201
# Components needed to reach 90% variance: 201
# Components needed to reach 95% variance: 201

# %% [markdown]
# ## **9. Cluster-to-Class Labeling and Evaluation against Weak Labels**
# Assign PII/non-PII labels to DBSCAN clusters using weak-label proportion threshold.This section also includes  Visualization of Classification Metrics:Bar chart summarizing precision, recall, and F1 against weak labels.

# %% [markdown]
# This section converts unsupervised DBSCAN clusters into binary classifications of “PII present” or “non-PII” by applying a majority threshold (τ = 0.30) based on the proportion of weak labels contained in each cluster.
# The resulting cluster-level predictions are then quantitatively evaluated against the regex-based weak labels using standard performance metrics—precision, recall, and F₁-score—to assess how closely the clustering output aligns with the proxy labeling baseline.
# This evaluation provides insight into the consistency between the unsupervised clustering patterns and the rule-based PII proxies, thereby serving as an intermediary validation stage before integrating transformer-based models.

# %%
# Cluster->PII mapping by majority of weak labels (threshold τ)
tau = 0.30
cluster_ids = np.unique(labels[labels != -1])
cluster_to_pii = {c: int(y_true[labels == c].mean() >= tau) for c in cluster_ids}
y_pred = np.array([cluster_to_pii.get(l, 0) for l in labels])  # noise -> 0 (non-PII) by default

# Metrics (vs weak labels) + quick summary for slides
prec = precision_score(y_true, y_pred, zero_division=0)
rec  = recall_score(y_true, y_pred, zero_division=0)
f1   = f1_score(y_true, y_pred, zero_division=0)

print(f"DBSCAN eps={best_eps} | silhouette={sil:.3f} | DBI={dbi:.3f} | noise={(labels==-1).mean():.1%}")
print(f"Weak-label positives: {y_true.sum()} of {len(y_true)} ({y_true.mean():.1%})")
print(f"Precision={prec:.3f} | Recall={rec:.3f} | F1={f1:.3f}")


metrics = ["Precision", "Recall", "F1 score"]
scores  = [prec, rec, f1]  # or [0.955, 0.476, 0.635]

fig, ax = plt.subplots(figsize=(6,4))
ax.bar(metrics, scores, zorder=2)

ax.set_title("Classification Metrics vs. Weak Labels")
ax.set_ylabel("Score")
ax.set_ylim(0, 1.05)            # headroom above 1.0
ax.set_axisbelow(True)           # draw grid behind bars/text
ax.yaxis.grid(True, linestyle="--", alpha=0.4, zorder=0)

# value labels (avoid overlap with grid/top)
for i, v in enumerate(scores):
    y = min(v + 0.03, ax.get_ylim()[1] - 0.02)
    ax.text(i, y, f"{v:.3f}", ha="center", va="bottom", zorder=3)

plt.tight_layout()
plt.show()
# Out:
# DBSCAN eps=0.5 | silhouette=0.417 | DBI=1.021 | noise=59.8%
# Weak-label positives: 3836 of 5000 (76.7%)
# Precision=0.967 | Recall=0.481 | F1=0.643

# %% [markdown]
# ## **10. Classification Report – Model Performance**
# Generate full report (precision, recall, F1, support) for hybrid predictions.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=["Non-PII", "PII"]))
# Out:
#               precision    recall  f1-score   support
#
#      Non-PII       0.36      0.95      0.52      1164
#          PII       0.97      0.48      0.64      3836
#
#     accuracy                           0.59      5000
#    macro avg       0.66      0.71      0.58      5000
# weighted avg       0.83      0.59      0.61      5000

# %% [markdown]
# ## **11. Threshold Optimization (τ Sweep)**
# Systematically test multiple τ values to refine cluster-to-label mapping.
#
# This step tests multiple cluster-level probability thresholds (τ) to map clusters to PII/non-PII predictions. Precision, recall, and F1 are computed for each τ to identify the optimal balance between sensitivity and specificity.

# %%
import numpy as np, pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score

assert "labels" in globals() and "y_true" in globals(), "Run clustering and weak-label creation first."

taus = [0.90, 0.70, 0.50, 0.30]
cluster_ids = np.unique(labels[labels != -1])

def preds_at_tau(tau):
    # cluster-level P(PII) using weak labels
    c2pii = {c: int(y_true[labels == c].mean() >= tau) for c in cluster_ids}
    # default: DBSCAN noise (-1) → non-PII
    return np.array([c2pii.get(l, 0) for l in labels])

rows = []
for t in taus:
    y_hat = preds_at_tau(t)
    rows.append({
        "tau": t,
        "precision": precision_score(y_true, y_hat, zero_division=0),
        "recall":    recall_score(y_true, y_hat, zero_division=0),
        "f1":        f1_score(y_true, y_hat, zero_division=0)
    })

tau_report = pd.DataFrame(rows).sort_values("tau", ascending=False)
print(tau_report.to_string(index=False, float_format=lambda v: f"{v:.3f}"))
# Out:
#   tau  precision  recall    f1
# 0.900      0.999   0.458 0.628
# 0.700      0.998   0.462 0.632
# 0.500      0.969   0.480 0.642
# 0.300      0.967   0.481 0.643

# %% [markdown]
# ## **12. BERT-Based Named Entity Recognition (NER)**
# Run transformer model (`dslim/bert-base-NER`) to extract PII entities (PER, ORG, LOC)

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

def detect_bert_pii(text):
    entities = ner_pipeline(text)
    pii_tags = {"PER", "ORG", "LOC"}
    return int(any(ent["entity_group"] in pii_tags for ent in entities))

notes_df["bert_pii"] = notes_df["TEXT"].apply(lambda t: detect_bert_pii(t[:512]))  # limit length for efficiency
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cuda:0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %% [markdown]
# ## **13. Regex + BERT Hybrid Weak Label Integration**
# Combine outputs into unified hybrid labels for improved PII detection.

# %%
# 3) Weak labels (proxy PII) – MIMIC placeholders + common PHI regexes + BERT Labels
PII_PATTERNS = [
    r"\[\*\*.*?\*\*\]",  # MIMIC redaction placeholders (proxy for PHI locations)
    r"\b\d{3}-\d{2}-\d{4}\b",  # SSN
    r"\b(?:\+?1[\s.-]?)?(?:\(\d{3}\)|\d{3})[\s.-]?\d{3}[\s.-]?\d{4}\b",  # phone
    r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b",  # email
    r"\b\d{1,5}\s+[A-Za-z0-9.\- ]+\s+(?:St|Street|Ave|Avenue|Rd|Road|Blvd|Lane|Ln|Dr|Drive)\b",  # address-ish
    r"\b\d{5}(?:-\d{4})?\b"  # ZIP
]
rx = re.compile("|".join(PII_PATTERNS))
notes_df["proxy_pii"] = notes_df["TEXT"].str.contains(rx).astype(int)  # 1 if any proxy PII pattern, else 0

notes_df["combined_pii"] = ((notes_df["proxy_pii"] + notes_df["bert_pii"]) > 0).astype(int)
y_true = notes_df["combined_pii"].to_numpy()

# %% [markdown]
# ## **14. Visualization – Hybrid Label Metrics Comparison**
# Plot performance (precision, recall, F1) for hybrid vs. individual labeling methods.

# %%
# --- 6) Cluster -> PII mapping by majority of HYBRID weak labels (regex ∪ BERT) ---
# Assumes you already created:
# notes_df["proxy_pii"], notes_df["bert_pii"], notes_df["combined_pii"]
# and set: y_true = notes_df["combined_pii"].to_numpy()

tau = 0.30
cluster_ids = np.unique(labels[labels != -1])
cluster_to_pii = {c: int(y_true[labels == c].mean() >= tau) for c in cluster_ids}
y_pred = np.array([cluster_to_pii.get(l, 0) for l in labels])  # noise -> 0 (non-PII)

# --- 7) Metrics (vs HYBRID weak labels) + concise summary for slides ---
from sklearn.metrics import precision_score, recall_score, f1_score

prec = precision_score(y_true, y_pred, zero_division=0)
rec  = recall_score(y_true, y_pred, zero_division=0)
f1   = f1_score(y_true, y_pred, zero_division=0)

n = len(y_true)
regex_pos = int(notes_df["proxy_pii"].sum())
bert_pos  = int(notes_df["bert_pii"].sum())
union_pos = int(notes_df["combined_pii"].sum())
intersect_pos = int(((notes_df["proxy_pii"] == 1) & (notes_df["bert_pii"] == 1)).sum())

print(f"DBSCAN eps={best_eps} | silhouette={sil:.3f} | DBI={dbi:.3f} | noise={(labels==-1).mean():.1%}")
print(f"Hybrid weak-label (regex ∪ BERT) positives: {union_pos} of {n} ({union_pos/n:.1%})")
print(f"  - Regex-only positives: {regex_pos} ({regex_pos/n:.1%})")
print(f"  - BERT-only positives:  {bert_pos} ({bert_pos/n:.1%})")
print(f"  - Intersection (regex ∩ BERT): {intersect_pos} ({intersect_pos/n:.1%})")
print(f"Precision={prec:.3f} | Recall={rec:.3f} | F1={f1:.3f}")
# Out:
# DBSCAN eps=0.5 | silhouette=0.417 | DBI=1.021 | noise=59.8%
# Hybrid weak-label (regex ∪ BERT) positives: 3908 of 5000 (78.2%)
#   - Regex-only positives: 3836 (76.7%)
#   - BERT-only positives:  997 (19.9%)
#   - Intersection (regex ∩ BERT): 925 (18.5%)
# Precision=0.946 | Recall=0.477 | F1=0.635

# %% [markdown]
# ## **15. Extraction and Analysis of Prefix Tokens Before PII Entities**
# Identify frequent tokens preceding PII entities to examine contextual patterns.This cell identifies and summarizes short prefix phrases that occur immediately before PII (e.g., “my name is,” “social security number,” “phone number”). Using regular expressions for common PII types, it extracts up to 60 characters before each match, aggregates prefix frequencies by PII type, and prints redacted concordance lines for audit. This approach aligns interpretability with PII morphology and, allowing the verify that detections arise from realistic cue phrases and to spot error modes (e.g., placeholder saturation or missing cues). The resulting prefix counts can inform feature augmentation (cue-phrase indicators, character n-grams) and operating-point selection in the refinement steps.

# %%
# Prefixes before PII (very short version)
import re, pandas as pd

assert "notes_df" in globals() and "TEXT" in notes_df

PII = re.compile(r"(.{0,60}?)(\b\d{3}-\d{2}-\d{4}\b|"                 # SSN
                 r"\b(?:\+?1[\s.\-]?)?(?:\(\d{3}\)|\d{3})[\s.\-]?\d{3}[\s.\-]?\d{4}\b|"  # phone
                 r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b|"                  # email
                 r"\b\d{5}(?:-\d{4})?\b|"                                                # ZIP
                 r"\b\d{1,2}[/-]\d{1,2}[/-]\d{2,4}\b)", re.I)                            # date mm/dd/yyyy

pref, samp = [], []
for txt in notes_df["TEXT"].astype(str):
    for m in PII.finditer(txt):
        left = " ".join(re.findall(r"\b\w+\b", m.group(1))[-4:]).lower()   # last 4 tokens before PII
        pref.append(left)
        s, e = m.span(2)
        ctx = txt[max(0, s-35): min(len(txt), e+35)]
        samp.append((left, re.sub(re.escape(m.group(2)), "[PII]", ctx)))

# Top prefixes
print(pd.Series(pref).value_counts().head(15).to_string())

# Sample redacted concordance lines
print("\nSamples:")
print(pd.DataFrame(samp, columns=["prefix","concordance"]).groupby("prefix").head(2).to_string(index=False))
# Out:
# dr last name stitle                    218
# job job number                         212
# telephone fax 1                        109
# by last name namepattern1               71
# mr known lastname                       63
# phone telephone fax 1                   61
# d md number 1                           42
# ms known lastname                       41
# at telephone fax 1                      40
# attending first name3 lf                37
# namepattern1 last name namepattern1     36
# namepattern2 last name namepattern1     35
# date range 1                            29
# known lastname                          29
# last name namepattern1                  26
#
# Samples:
#                                prefix                                                                         concordance
#            clip clip number radiology         Clip # [**Clip Number (Radiology) [PII]**]\n Reason: 73 Y/O MAN WITH AGGRES
#                                 abg 7     u: 13 cmH2O\n   SPO2: 98%\n   ABG: 7.[PII]/23/0\n   Ve: 12.1 L/min\n   Physical
#                                 abg 7     5 cmH2O/mL\n   SPO2: 100%\n   ABG: 7.[PII]/24/0\n   Ve: 8.2 L/min\n   PaO2 / Fi
#                    cc cc contact info       f Complaint:\nCC:[**CC Contact Info [PII]**]\nMajor Surgical or Invasive Proc
#     provider first name8 namepattern2         der: [**First Name8 (NamePattern2) [PII]**] [**Last Name (NamePattern1) **]
#              attending first name3 lf     ugs\n\nAttending:[**First Name3 (LF) [PII]**]\nChief Complaint:\nElective nephr
#                  call telephone fax 1         weeks. Call ([**Telephone/Fax (1) [PII]**] to make an appointment.\nPlease
#            patient took two hospital1        The\npatient took two [**Hospital1 [PII]**] nitroglycerin tablets with\nmini
#                gave ms known lastname         amedics gave Ms. [**Known lastname [PII]**] [**Last Name (Titles) 37736**]
#                      last name titles        ame 18531**] [**Last Name (Titles) [PII]**] nitroglycerin\nspray which made
#                      last name stitle        est with Dr.\n[**Last Name (STitle) [PII]**] at [**Location (un) 47**] in tw
#             by last name namepattern1     ted By:[**Last Name (NamePattern1) [PII]**]\n\nMEDQUIST36\n\nD:  [**2149-1-16**
#                        job job number                        -21**]  06:12\nJOB#:  [**Job Number [PII]**]\n\n\n\n\n\n\n\n
#                   dr last name stitle         nerve.  Dr. [**Last Name (STitle) [PII]**] from the\nDepartment of Anesthes
#                        job job number                                      2-4**]  18:15\nJOB#:  [**Job Number [PII]**]\n
#                             hospital1        ake a reduced dose of\n[**Hospital1 [PII]**] given [**Hospital1 7968**] CrCl
#                      name initial pre        Tablet daily\n[**Name Initial (PRE) [PII]**] 100 mg QAM, 200mg 4pm, 300mg 8p
#                          12 hospital1        et PO once a day.\n12. [**Hospital1 [PII]**] 2.5 mg Tablet Sig: One (1) Tabl
#                dear mr known lastname      uctions:\nDear Mr [**Known lastname [PII]**],\n\nIt was a pleasure caring for
#               titles last name titles         (Titles) **] [**Last Name (Titles) [PII]**] to 300mg by mouth every other d
#                   dr last name stitle        contact Dr. [**Last Name (STitle) [PII]**] regarding new blood\ncultures\n-s
#                       name ni name ni        6**] [**Name (NI) **] [**Name (NI) [PII]**] [**Telephone/Fax (1) 69422**]\n.
#                       telephone fax 1      (NI) 69420**] [**Telephone/Fax (1) [PII]**]\n.\n# Prophylaxis:\nLovenox sc, PP
#                  each winter in state       they spend each winter in [**State [PII]**]. When asked about\n\nhobbies, she
#             hobbies she reports state    out\n\nhobbies, she reports [**State [PII]**] as one of her hobbies.\n\n\nFamily
#              attending first name3 lf     nix\n\nAttending:[**First Name3 (LF) [PII]**]\nChief Complaint:\nshortness of b
#                         pt is name ni       /p PPM for CHB, pt is [**Name (NI) [PII]**].\n.\n#BPH: Patient should continu
#                  1692 telephone fax 1         (NI) 1692**] [**Telephone/Fax (1) [PII]**], son [**Name (NI) **]\n[**Teleph
#                       telephone fax 1        Name (NI) **]\n[**Telephone/Fax (1) [PII]**] both are HCPs, [**Name (NI) 709
#       pattern1 last name namepattern4         1) **] [**Last Name (NamePattern4) [PII]**], MD Phone:[**Telephone/Fax (1)
#          firstname 122 known lastname         firstname 122**] [**Known lastname [PII]**] is an 85 year old male with a p
#                     mr known lastname        ial History:\nMr. [**Known lastname [PII]**] lives in an [**Hospital3 **] fa
#       hospital1 18 numeric identifier        pital1 18**] [**Numeric Identifier [PII]**]Portable TTE\n(Complete) Done [**
#        doppler test location location        Doppler Test Location: [**Location [PII]**]/[**Hospital Ward Name 121**] 6\n
#                  18 mr known lastname         n [**4-18**] Mr. [**Known lastname [PII]**] [**Last Name (Titles) 1834**] a
#                  1110 telephone fax 1         (un) 1110**] [**Telephone/Fax (1) [PII]**].  All follow-up appointments\nwe
#                    weeks last name lf      ent for 2 weeks. [**Last Name (LF) [PII]**], [**Name8 (MD) **] MD\n\n\nPlease
#           address apartment address 1        N\nAddress: [**Apartment Address(1) [PII]**], [**Location (un) **],[**Numeri
#        location un numeric identifier        ion (un) **],[**Numeric Identifier [PII]**]\nPhone: [**Telephone/Fax (1) 825
#                 phone telephone fax 1       490**]\nPhone: [**Telephone/Fax (1) [PII]**]\nFax: [**Telephone/Fax (1) 90191
#                   fax telephone fax 1      82564**]\nFax: [**Telephone/Fax (1) [PII]**]\n\n**Please call cardiac surgery
#              up at university college       follow up at [**University/College [PII]**] on [**2108-6-11**].\n\n# ETOH wit
#            seen at university college        l be seen at [**University/College [PII]**] on [**6-11**]. He should\ncontin
#                       from dr name ni        ons: confirmed from Dr[**Name (NI) [PII]**] office his PCP at\n[**Name9 (PRE
#                dear mr known lastname      uctions:\nDear Mr [**Known lastname [PII]**],\n\nIt was a great pleasure takin
#              11 at university college       8-6-11**] at [**University/College [PII]**] as instructed to you.\n.\nDepartm
#           2801 last name namepattern4         801**] [**Last Name (NamePattern4) [PII]**], NP [**Telephone/Fax (1) 7976**
#                 phone telephone fax 1                                1) **]\nPhone: [**Telephone/Fax (1) [PII]**]\n\n\n\n
#                     mr known lastname        ent Illness:\nMr. [**Known lastname [PII]**] is a 46 year old man with known
#                  16 mr known lastname         2145-2-16**] Mr. [**Known lastname [PII]**] was brought to the operating ro
#                   pre telephone fax 1        e9 (PRE) **] ([**Telephone/Fax (1) [PII]**] in [**2-2**] weeks.\nPlease see
#          namepattern1 telephone fax 1       attern1) **] ([**Telephone/Fax (1) [PII]**] in [**2-2**]\nweeks.\nPlease see
#          namepattern1 telephone fax 1     attern1) **] ([**Telephone/Fax (1) [PII]**] in [**5-7**]\nweeks.\n\n\nCompleted
#        known firstname known lastname         wn firstname **] [**Known lastname [PII]**] is a 58 year old male with a hi
#   namepattern1 last name namepattern1        1) **] [**Last Name (NamePattern1) [PII]**] on\nWednesday, [**2153-4-18**] a
#                           location un      18**] at 1:00 pm.\n[**Location (un) [PII]**]\nSuite #4\n[**Location (un) **],
#        location un numeric identifier       on (un) **], [**Numeric Identifier [PII]**]\n\nPlease call your primary care
#               atonic doctor last name        ion of atonic, [**Doctor Last Name [PII]**] mal or myoclonic jerks very\nbri
#               yearly doctor last name        *] with\nyearly [**Doctor Last Name [PII]**] scales and biyearly neuropsycho
#                     d telephone fax 1        eric- 2400/d, [**Telephone/Fax (1) [PII]**]\nkeppra- generic- 2500/d, 1000/1
#          06 probnp numeric identifier        0.06* proBNP-[**Numeric Identifier [PII]**]*\n[**2121-6-4**] 11:12AM BLOOD D
#                           32 36 abg 7       a.\nO2 sat 87% 4L w RR 32-36. ABG 7.[PII] w HCO3 46. She was\ntransferred to
#                             hospital3       NamePattern1) 1726**]\n[**Hospital3 [PII]**]\nWednesday, [**3-29**], at 1:30P
#                         t md number 3         . You were given t-[**MD Number(3) [PII]**] is a medicine to break up the b
#                    at telephone fax 1         ion Office at [**Telephone/Fax (1) [PII]**] to update your personal and dem
#                        n v d hospital        0-12-24**] with\nN/V/D, [**Hospital [PII]**] transferred to [**Hospital1 18*
#                  wife telephone fax 1      NICATION wife [**Telephone/Fax (1) [PII]**]\n\nMedications on Admission:\nglar
#                      last name stitle        sults to Dr.\n[**Last Name (STitle) [PII]**] at [**Telephone/Fax (1) 29683**
#                    at telephone fax 1      ) 10543**] at [**Telephone/Fax (1) [PII]**]\n\n\n[**Telephone/Fax (1) **] Disp
#         namepattern4 last name stitle         ttern4) **]. [**Last Name (STitle) [PII]**], and you can discuss the result
#                     from date range 1      ery 4 hours from [**Date range (1) [PII]**]\n(3weeks total)\n#. STOP Zetia\n#.
#                    md telephone fax 1        ern1) **], MD [**Telephone/Fax (1) [PII]**]\nBuilding: SC [**Hospital Ward N
#                     ms known lastname       7**] cath.\n.\nMs. [**Known lastname [PII]**] saw her cardiologist on the day
#                note ms known lastname       .\n.\nOf note, Ms. [**Known lastname [PII]**] also has been experiencing diff
#            636 last name namepattern1       636**] [**Last Name (NamePattern1) [PII]**] on [**2142-5-5**].\n.\n[**5-7**]
#                       in last name lf         ed large clot in [**Last Name (LF) [PII]**], [**First Name3 (LF) **] cardio
#                fall ms known lastname         6) s/p fall: Ms. [**Known lastname [PII]**] fell while ambulating in her ro
#                    mrs known lastname        tal Course:\nMrs. [**Known lastname [PII]**] is a 47 year old woman s/p roux
#               8 evaluated in hospital         94-9-8**] Evaluated in [**Hospital [PII]**] Clinic. Found to have worsening
#            computers street address 1        on: Computers [**Street Address(1) [PII]**] Bank.\n- Exposures: Worked for a
#             recently moved from state        , who recently moved from [**State [PII]**] to MA for\nmedical care and now
#       hospital1 18 numeric identifier        pital1 18**] [**Numeric Identifier [PII]**] (Complete)\nDone [**2146-1-17**]
#                      street address 2       ame3 (LF) **]\n[**Street Address(2) [PII]**]\n[**Location (un) 15116**], [**N
#                           location un        dress(2) 15115**]\n[**Location (un) [PII]**], [**Numeric Identifier 15117**]
#                    numeric identifier         n) 15116**], [**Numeric Identifier [PII]**]  Status: Inpatient DOB: [**2093
#                   base in location un         Air Force Base in [**Location (un) [PII]**] this past Friday evening with p
#                          atrium a v m     K\n**PRESSURES\nRIGHT ATRIUM {a/v/m} [PII]\nRIGHT VENTRICLE {s/ed} 47/33\nPULMO
#                          artery s d m      ed} 47/33\nPULMONARY ARTERY {s/d/m} [PII]\nPULMONARY WEDGE {a/v/m} 33/34/32\nP
#                           wedge a v m      } 47/34/40\nPULMONARY WEDGE {a/v/m} [PII]\nPERICARDIUM {m} 33\n**CARDIAC OUTPU
#                    to the location un         ransferred to the [**Location (un) [PII]**] Center for Rehab in [**Location
#                  rehab in location un        nter for Rehab in [**Location (un) [PII]**],\n[**Location (un) 3844**] for f
#                       call dr name ni        ns:\n1. Please call Dr.[**Name (NI) [PII]**] office, [**Telephone/Fax (1) 9*
#                is relatively name2 ni         there is relatively [**Name2 (NI) [PII]**] superficial to mid\ndermal periv
#                         on room air 7        1.4.  ABG initially\non room air 7.[PII]/12, lactate 5.4.  Chest x-ray on\na
#                the hospital ward name        itted to the [**Hospital Ward Name [PII]**] Intensive\nCare Unit with an asp
#                        known lastname        pparent that Mr.\n[**Known lastname [PII]**] had a new left-sided facial dro
#             by last name namepattern1     ted By:[**Last Name (NamePattern1) [PII]**]\n\nMEDQUIST36\n\nD:  [**2146-12-14*
#                   st doctor last name        esented to St. [**Doctor Last Name [PII]**], he had urinary\nretention requi
#                   st doctor last name       ization at\nSt. [**Doctor Last Name [PII]**].\nHe was continued on nicotine p
#                     h telephone fax 1        (NI) 8214**]\nh[**Telephone/Fax (1) [PII]**], c[**Telephone/Fax (1) 79340**]
#                     c telephone fax 1        1) 79339**], c[**Telephone/Fax (1) [PII]**]\n# Code: DNR/DNI (discussed with
#                 busy shift at company        extremely busy shift at [**Company [PII]**]. She missed her\nmorning and eve
#                     ms known lastname        ent Illness:\nMs. [**Known lastname [PII]**] is a 81yo R-handed woman with d
#               relative sister name ni        rect relative (sister [**Name (NI) [PII]**]\nin [**Name (NI) 1056**] was cal
#                       dtr in name2 ni      0.\n\nREFLEXES:\nDTR in [**Name2 (NI) [PII]**] 2+ bilaterally; absent in Ach;
#                 weeks telephone fax 1        -26**] weeks. [**Telephone/Fax (1) [PII]**]\npleas call to schedule appointm
#                   unit at location un          Dialysis Unit at [**Location (un) [PII]**], and follows with Dr. [**First
#   namepattern1 last name namepattern1        1) **] [**Last Name (NamePattern1) [PII]**]; saw Dr.\n[**Last Name (STitle)
#                  dictated by name8 md    7551**]\n\nDictated By:[**Name8 (MD) [PII]**]\nMEDQUIST36\n\nD:  [**2106-4-26**]
#                        ni 449 name ni         , [**Name (NI) 449**] [**Name (NI) [PII]**] #[**Telephone/Fax (1) 38825**],
#                        ni 449 name ni        , [**Name (NI) 449**] [**Name (NI) [PII]**],\n[**Telephone/Fax (1) 38826**]
#           prefixes last name prefixes       fixes) **] [**Last Name (Prefixes) [PII]**] to\nRCA\nNoted to be in AIVR with
#             store director of company       ks as store director of [**Company [PII]**] (states is very\nstressful).\nPt
#                   701 telephone fax 1     (un) 701**]- ([**Telephone/Fax (1) [PII]**]\n\n\nTransitional Issues:\n========
#                contact either name ni         ree to contact either [**Name (NI) [PII]**] [**Last Name (NamePattern1) 171
#                last name namepattern1        348**] [**Last Name (NamePattern1) [PII]**], [**Name (NI) 4207**] 3 or\nDr.
#                       two age over 90        L Solution Sig:\nTwo [**Age over 90 [PII]**]y (280) mg Intravenous every eig
#           with last name namepattern5        \nWith: [**Last Name (NamePattern5) [PII]**], MD, PHD [**Telephone/Fax (1) 2
#            unit no numeric identifier          Unit No:  [**Numeric Identifier [PII]**]\nAdmission Date: [**2197-2-2**]\n
#                         mom g name ni        a 27-year-old mom, G, [**Name (NI) [PII]**], with prenatal\nlabs including t
#         name namepattern1 at hospital          (NamePattern1) **] at [**Hospital [PII]**] which is located at [**Location
#                located at location un        ich is located at [**Location (un) [PII]**],\n[**Hospital1 392**], [**Numeri
#      hospital1 392 numeric identifier     tal1 392**], [**Numeric Identifier [PII]**].\n\nCARE/RECOMMENDATIONS:\n\nFEEDIN
#                          last name un        pneumococcal  7-\n[**Last Name (un) [PII]**] conjugant vaccine on [**4-9**],
#              namepattern4 md number 1       NamePattern4) **], [**MD Number(1) [PII]**]\n\nDictated By:[**Last Name (Name
#             by last name namepattern4       ted By:[**Last Name (NamePattern4) [PII]**]\nMEDQUIST36\nD:  [**2197-5-10**]
#              was brought to hospital3       d.  He was brought to [**Hospital3 [PII]**].\n\nOn arrival to [**Hospital1 **
#                             hospital3      ended Care\n\nFacility:\n[**Hospital3 [PII]**] Center - [**Location (un) 5450*
#   namepattern2 last name namepattern1         2) **] [**Last Name (NamePattern1) [PII]**], [**Name Initial (NameIs) **].D
#                 old male from country        A 19-year-old male from [**Country [PII]**]\nwho moved to the U.S. in early
#           social history from country      \n\nSOCIAL HISTORY:  From [**Country [PII]**], attending school in the U.S.,\n
#                               name ni      tologist and PCP.\n.\n# [**Name (NI) [PII]**] ESRD\nPt's HD schedule is T/Th/S
#                      home month day 4        n admission. Home [**Month/Day (4) [PII]**] patch,\nlabetalol, lisinopril, a
#                             name9 pre       e PO\nDAILY (Daily).\n[**Name9 (PRE) [PII]**] 0.3 mg/24 hr Patch Weekly [**Na
#                           3 hospital1       \nPO DAILY (Daily).\n3. [**Hospital1 [PII]**] 0.3 mg/24 hr Patch Weekly [**Ho
#         physician discussed name9 pre        physician discussed [**Name9 (PRE) [PII]**] risks of high\nand low blood sug
#                       call dr name ni       day.\n.\nPlease call Dr.[**Name (NI) [PII]**] office [**Name (NI) 766**] morn
#                     abg notable for 7        d levo 750mg x1. ABG notable for 7.[PII]/44.\nShe was started on BiPAP and B
#                center telephone fax 1        seling Center [**Telephone/Fax (1) [PII]**]\n- Please call the [**Location (
#                  seen in the hospital         need to be seen in the [**Hospital [PII]**] Clinic by Dr. [**Last Name (STi
#                              hospital    en option #3 to get to\n[**Hospital [PII]**] clinic\n\n\n\nCompleted by:[**2147-
#                     from date range 1         as admitted from [**Date range (1) [PII]**] to [**Hospital1 **] [**Location
#                           0 143 abg 7        Cr 1.2, CK 26, Trop T\n0.143. ABG 7.[PII] on PEEP5, Fi02 1. Blood cultures w
#                          last name un        ent, hyperlipid,\n[**Last Name (un) [PII]**]-[**Doctor Last Name 122**] dise
#                      doctor last name       (un) 32665**]-[**Doctor Last Name [PII]**] disease.\n\nPhysical Exam:\nT: 98.
#               later ms known lastname       ely.\n\nLater, Ms. [**Known lastname [PII]**] pulled out her NG tube repeated
#                      doctor last name        her underlying\n[**Doctor Last Name [PII]**] disease vs. pain. Her blood pre
#              plavix ms known lastname         and plavix. Ms. [**Known lastname [PII]**] also suffered a small\npneumotho
#              course ms known lastname         her course, Ms. [**Known lastname [PII]**] developed\nincreasing secretions
#                       of last name un         euro: History of [**Last Name (un) [PII]**] [**Doctor Last Name 11042**] di
#                   on street address 2          33330**]) on [**Street Address(2) [PII]**] in [**Hospital1 1474**], [**Loc
#            hospital1 1474 location un       ospital1 1474**], [**Location (un) [PII]**].\n\nIf there are problems with th
#                 at hospital unit name         s located at [**Hospital Unit Name [PII]**], [**Location (un) 86**], [**Num
#                   fax telephone fax 1                                  2981**] Fax: [**Telephone/Fax (1) [PII]**]\n\n\n\n
#           7054 lot numeric identifier        : 7054; Lot: [**Numeric Identifier [PII]**]) was placed\nsuccessfully in the
#                    numeric identifier        : 7065; Lot:\n[**Numeric Identifier [PII]**]) was placed successfully in the
#                     p telephone fax 1     F) 1730**] P. [**Telephone/Fax (1) [PII]**]\n\n\nDischarge Disposition:\nExtend
#                              hospital      tended Care\n\nFacility:\n[**Hospital [PII]**] Healthcare & Rehabilitation Cen
#         namepattern4 last name stitle        ttern4) **]. [**Last Name (STitle) [PII]**] - in [**2-17**] weeks\nLocal car
#     name4 namepattern1 known lastname        amePattern1) **] [**Known lastname [PII]**]\nwas born at 40-2/7 weeks gestat
#                        md md number 2       Name8 (MD) **], MD [**MD Number(2) [PII]**]\n\nDictated By:[**Last Name (Name
#           4468 last name namepattern1         468**] [**Last Name (NamePattern1) [PII]**], Pulmonary at [**Hospital3 1810
#                    is telephone fax 1        one number is [**Telephone/Fax (1) [PII]**].  The\nparents have been instruc
#                last name namepattern1      me **]\n[**Last Name (NamePattern1) [PII]**].\n\n11.  SKIN:  Capillary hemangi
#           dr first name4 namepattern1          Dr. [**First Name4 (NamePattern1) [PII]**] [**Last Name (NamePattern1) 130
#                number telephone fax 1         hone number:  [**Telephone/Fax (1) [PII]**].  Fax number:  [**Telephone/Fax
#                number telephone fax 1        Fax number:  [**Telephone/Fax (1) [PII]**].\n\nCARE/RECOMMENDATIONS:  Contin
#                    30 telephone fax 1        3**]\nat 1:30, [**Telephone/Fax (1) [PII]**], Pulmonology, Dr. [**First Name
#           4468 last name namepattern1        468**] [**Last Name (NamePattern1) [PII]**], at the\n[**Hospital3 1810**], t
#                   vna telephone fax 1      versified VNA [**Telephone/Fax (1) [PII]**].\n\nDISCHARGE DIAGNOSIS:\n1.  Form
#                         d md number 1       rn1) 1877**], M.D. [**MD Number(1) [PII]**]\n\nDictated By:[**Last Name (Name
#       pattern1 last name namepattern1        1) **] [**Last Name (NamePattern1) [PII]**], M.D. [**MD Number(1) 24755**]\n
#                         d md number 1       n1) 34978**], M.D. [**MD Number(1) [PII]**]\n\nDictated By:[**Name8 (MD) 8736
#             who presented to hospital        male\nwho presented to [**Hospital [PII]**] Clinic for Mohs revision\nsurger
#                     1661 last name un        ion (un) 1661**]-[**Last Name (un) [PII]**]\ncontinue to function and put ou
#                   on last name stitle       re clear.\n\nOn[**Last Name (STitle) [PII]**]perative day six, on the day of
#             at last name namepattern1       eon at [**Last Name (NamePattern1) [PII]**])\nDepartment: TRANSPLANT\nWhen: M
#             lastname last name titles         lastname **] [**Last Name (Titles) [PII]**] [**12-2**] ppd x 10 years. He s
#                         to dr name ni        d to call it in to Dr.[**Name (NI) [PII]**] clinic.\n6.  Patient was also in
#              inspiratory last name un        e of inspiratory [**Last Name (un) [PII]**].  Chest x-ray was found\nto be n
#               expiratory last name un        y and expiratory [**Last Name (un) [PII]**] on\nexamination.  The patient wa
#                      and last name un        atory wheeze and [**Last Name (un) [PII]**]\nbilaterally, decreased breath s
#                      his last name un        eported that his [**Last Name (un) [PII]**] symptoms\nhad significantly impr
#                  dictated by name8 md    2362**]\n\nDictated By:[**Name8 (MD) [PII]**]\nMEDQUIST36\n\nD:  [**2170-1-17**]
#                          somnelence 7        Received ABG based on\nsomnelence 7.[PII] on 2l nasal canula, lactate 1.1. V
#               titles last name titles         (Titles) **] [**Last Name (Titles) [PII]**] engineering at [**University/Co
#     engineering at university college        gineering at [**University/College [PII]**], but\nretired on disability afte
#           pneumonia mr known lastname         pneumonia-  Mr. [**Known lastname [PII]**] was admitted with\nleukocytosis
#                         by dr name ni        .   He was seen by Dr.[**Name (NI) [PII]**]\nservice, who recommended treatm
#                        per dr name ni        im\ntoo sleepy, per Dr.[**Name (NI) [PII]**] note a day prior to admission,
#                        known lastname        o admission, Mr.\n[**Known lastname [PII]**] was pleced on a wean to start h
#       pattern1 last name namepattern1         1) **] [**Last Name (NamePattern1) [PII]**], MD (infectious diseases) Phone
#                 status sister name ni        inical status; sister [**Name (NI) [PII]**] identified herself as\nclosest l
#                    64 telephone fax 3      Tc P QRS T\n64 [**Telephone/Fax (3) [PII]**]/479 24 67 9\n.\nCHEST (PORTABLE A
#                    92 telephone fax 2      S T\n82 178 92 [**Telephone/Fax (2) [PII]**]9 31\n.\nCHEST (PORTABLE AP) Study
#           dr first name4 namepattern1         h Dr.[**First Name4 (NamePattern1) [PII]**] [**Last Name (NamePattern1) 328
#                  considered hospital1        gies were\nconsidered. [**Hospital1 [PII]**] tox screen was within normal li
#        transferred here from hospital         transferred here from [**Hospital [PII]**]\n[**Hospital 107**] Hospital aft
#          primary care provider number      ur primary care [**Provider Number [PII]**]\nweek after discharge.\n\nWe also
#           00 first name9 namepattern2         0:00 [**First Name9 (NamePattern2) [PII]**] [**Doctor Last Name 1726**] (di
#               551 apartment address 1         un) 551**] [**Apartment Address(1) [PII]**], [**Location (un) **],[**Numeri
#                     micu date range 1       s.\n\nIn the MICU ([**Date range (1) [PII]**]), patient was intubated for air
#        address last name namepattern4         dress: [**Last Name (NamePattern4) [PII]**], #240, [**Last Name (un) 80982*
#                      240 last name un          80981**], #240, [**Last Name (un) [PII]**] BEACH,[**Numeric Identifier 809
#              beach numeric identifier       982**] BEACH,[**Numeric Identifier [PII]**]\nPhone: [**0-0-**]\nAppointment:
#                          at 82 on abg        ypercarbic with\nPCO2 at 82 on ABG ([PII]/127), intubated for resp distress
#           1123 last name namepattern1         123**] [**Last Name (NamePattern1) [PII]**] at [**Hospital **] Clinic [**21
#                           name stitle         (STitle) 3759**]\n[**Name (STitle) [PII]**] not amenable to palliative care
#                      day date range 1        PO twice a\nday: [**Date range (1) [PII]**]: 7.5mg qAM & 5.0mg qPM\n[**Date
#                          date range 1        qAM & 5.0mg qPM\n[**Date range (1) [PII]**]: 5.0mg qAM & 2.5mg qPM\n[**5-14*
#                          date range 1      qAM & 2.5mg qPM\n[**Date range (1) [PII]**]: 2.5mg qAM & 0mg qPM\n\n.\nDisp:*5
#                             hospital1   th Service\n\nFacility:\n[**Hospital1 [PII]**] VNA\n\nDischarge Diagnosis:\nPrima
#                stitle telephone fax 1       (STitle) **], [**Telephone/Fax (1) [PII]**], on\n[**5-9**] at 2:40.\n3. Pleas
#   namepattern2 last name namepattern1        2) **] [**Last Name (NamePattern1) [PII]**],\n[**Telephone/Fax (1) 79250**],
#                         by dr name ni         **Name (NI) **] by Dr.[**Name (NI) [PII]**] office ([**Telephone/Fax (1) 62
#           prefixes last name prefixes        fixes) **] [**Last Name (Prefixes) [PII]**] in CX. Referred for\ncabg to Dr.
#                    85 telephone fax 2        were 100.2 85 [**Telephone/Fax (2) [PII]**]% RA. On exam,\nshe was noted to
#                 admitted date range 1        ecently admitted [**Date range (1) [PII]**] with lethargy\nand abdominal pai
#                dear ms known lastname      ctions:\nDear Ms. [**Known lastname [PII]**],\n\nYou were recently admitted to
#                   ptitle last name un        5 (PTitle) **] & [**Last Name (un) [PII]**] [**Telephone/Fax (1) 857**]\nBui
#                       ni 4459 name ni        [**Name (NI) 4459**]: [**Name (NI) [PII]**] [x] EOMI [x]\nNeck:  Supple [x]
#                    mrs known lastname        tal Course:\nMrs. [**Known lastname [PII]**] was admitted and underwent rout
#                   3 ms known lastname        tiated.\nPOD#3 Ms.[**Known lastname [PII]**] went into postoperative rapid a
#                              name2 ni       .\nACTIVE PROBLEMS:\n# [**Name2 (NI) [PII]**] lead infection: Upon presentati
#                            date range      nd\nmoxifloxacin.\n.\n# [**Date Range [PII]**]-induced cardiomyopathy: ICD exc
#                           1 hospital1       scharge Diagnosis:\n1. [**Hospital1 [PII]**]-pocket infection\n2. s/p ASD rep
#                           4 hospital1      repair\n3. s/p MVR\n4. [**Hospital1 [PII]**] induced cardiomyopathy\n5. sCHF\n
#                un apartment address 1          (un) **], [**Apartment Address(1) [PII]**], [**Hospital1 **],[**Numeric Id
#          hospital1 numeric identifier       ospital1 **],[**Numeric Identifier [PII]**]\nPhone: [**0-0-**]\nAppointment:
#                    md telephone fax 1        ) 2477**], MD [**Telephone/Fax (1) [PII]**]\nBuilding: SC [**Hospital Ward N
#                           name stitle         (STitle) 72210**] [**Name (STitle) [PII]**] [**Hospital1 **], [**Hospital1
#                          day hospital      \n2.  Psychiatrist:\nDay [**Hospital [PII]**] Hospital\ntel:[**Telephone/Fax (
#                   tel telephone fax 1         Hospital\ntel:[**Telephone/Fax (1) [PII]**], fax: [**Telephone/Fax (1) 7221
#              doctor first name titles         care doctor [**First Name (Titles) [PII]**] [**Last Name (Titles) 2974**] o
#   namepattern4 last name namepattern1       4) **] [**Last Name (NamePattern1) [PII]**], M.D.\nFamily Practice\n[**Hospit
#                      street address 2       edical Center\n[**Street Address(2) [PII]**]\n[**Hospital 30890**] Medical As
#              mother received name2 ni        ve.  Mother received [**Name2 (NI) [PII]**]\nantibiotics prior to delivery.
#                   hospital2 hospital3        **], [**Hospital2 **] [**Hospital3 [PII]**],\nphone [**Telephone/Fax (1) 378
#       pattern1 last name namepattern4         1) **] [**Last Name (NamePattern4) [PII]**], M.D.  [**MD Number(1) 35941**]
#           2259 last name namepattern1         259**] [**Last Name (NamePattern1) [PII]**] (husband) [**Telephone/Fax (1)
#               husband telephone fax 1        **] (husband) [**Telephone/Fax (1) [PII]**]\n[**Name (NI) 2259**] [**Name (N
#                   son telephone fax 1        NI) **] (son) [**Telephone/Fax (1) [PII]**]\n[**Name (NI) **] (son) [**Telep
#                   son telephone fax 1        NI) **] (son) [**Telephone/Fax (1) [PII]**]\n[**Doctor First Name 3608**] (d
#              daughter telephone fax 1        *] (daughter) [**Telephone/Fax (1) [PII]**]\n[**Doctor First Name **] (daugh
#              daughter telephone fax 1      *] (daughter) [**Telephone/Fax (1) [PII]**]\n\nFamily History:\n[**Name (NI) 1
#             ck cpk numeric identifier        AM   CK(CPK)-[**Numeric Identifier [PII]**]*\n[**2206-5-14**] 10:00AM   estG
#             failure ms known lastname        ory failure: Ms. [**Known lastname [PII]**] presented with\nsignificant resp
#           initially ms known lastname        k: Initially Ms. [**Known lastname [PII]**] was hypotensive and placed\non p
#                clinic telephone fax 1        l **] clinic ([**Telephone/Fax (1) [PII]**].\nWarfarin was held on the day o
#           an first name9 namepattern2        , an [**First Name9 (NamePattern2) [PII]**] [**Last Name (un) **]\n(losartan
#           dr first name8 namepattern2          DR. [**First Name8 (NamePattern2) [PII]**] [**Last Name (NamePattern1) 115
#              first name8 namepattern2         Dr.\n[**First Name8 (NamePattern2) [PII]**] [**Last Name (NamePattern1) 115
#         with first name8 namepattern2         ith: [**First Name8 (NamePattern2) [PII]**] [**Last Name (NamePattern1) 115
#                         with name6 md        *] at 10:20 AM\nWith: [**Name6 (MD) [PII]**] [**Name8 (MD) 10161**], NP [**T
#                              name8 md         *Name6 (MD) 10160**] [**Name8 (MD) [PII]**], NP [**Telephone/Fax (1) 250**]
#                            dr name ni        utpatient basis at\nDr.[**Name (NI) [PII]**] discretion to evaluate the succ
#                    15l nrb abg showed        y presented on 15L NRB. ABG showed [PII]/288. She was\nplaced on BiPap at fi
#                     with last name un       s\nfollow up with [**Last Name (un) [PII]**] in [**2-4**] weeks\nfollow up wi
#                         with name6 md        *] at 10:00 AM\nWith: [**Name6 (MD) [PII]**] [**Name8 (MD) 18073**], RN [**T
#                              name8 md        *Name6 (MD) 18072**] [**Name8 (MD) [PII]**], RN [**Telephone/Fax (1) 22**]\n
#           4580 last name namepattern1       580**] [**Last Name (NamePattern1) [PII]**]\n[**3-7**], 8:50AM\n[**Location *
#                stitle telephone fax 1       (STitle) **] ([**Telephone/Fax (1) [PII]**].\n[**3-20**] at 2:30pm\nOne [**St
#           location numeric identifier       ocation **], [**Numeric Identifier [PII]**]\n\n3.) Gastroenterologist, Dr. [*
#                    is telephone fax 1                                ne number is ([**Telephone/Fax (1) [PII]**].\n\n\n\n
#                            11 name ni       [**Name (NI) **]\n\n11. [**Name (NI) [PII]**] pt is to be d/c'd back to [**Ho
#                was performed noting 7      and.  ABG was performed noting:  7.[PII] on 6L\nbipap 12/8.\n.\nReview of syst
#                name ni known lastname        [**Name (NI) **] [**Known lastname [PII]**] is a term\ninfant admitted to th
#            122 last name namepattern1         122**] [**Last Name (NamePattern1) [PII]**] - telephone No. [**Telephone/Fa
#                    no telephone fax 1        telephone No. [**Telephone/Fax (1) [PII]**], in one to two\nweeks after disc
#            622 last name namepattern1         622**] [**Last Name (NamePattern1) [PII]**]. Telephone No. [**Telephone/Fax
#                    no telephone fax 1        Telephone No. [**Telephone/Fax (1) [PII]**],\nbeeper No. 1241.  Genetics als
#                   state year 4 digits        EEN:  The state [**Year (4 digits) [PII]**] screen was sent\non [**2108-11-2
#                    hospital hospital3     yst.\n\n[**Hospital **] [**Hospital3 [PII]**] [**Serial Number 60043**]\n\nHead
#                         serial number       ospital3 60042**] [**Serial Number [PII]**]\n\nHead circumference on [**2108-
#              namepattern4 md number 1       NamePattern4) **], [**MD Number(1) [PII]**]\n\nDictated By:[**Last Name (Name
#           6971 lot numeric identifier        F\n6971 / LOT [**Numeric Identifier [PII]**]] biliary [**Numeric Identifier
#                       name ni name ni        iend [**Name (NI) **] [**Name (NI) [PII]**].  Given his advanced\nage and co
#                procrit at location un         Was on Procrit at [**Location (un) [PII]**], he did not receive this while
#             discharge telephone fax 1     f discharge.  [**Telephone/Fax (1) [PII]**]\n\n\n\nCompleted by:[**2114-7-12**]
#                 one mr known lastname        ive day one, Mr. [**Known lastname [PII]**] was awake, extubated and\nneurol
#                 weeks telephone fax 1        2-6**] weeks. [**Telephone/Fax (1) [PII]**]\nFollow-up with primary care phy
#                  2961 telephone fax 1        rn1) 2961**], [**Telephone/Fax (1) [PII]**] upon\ndischarge from the rehabil
#                   123 telephone fax 1         ern1) 123**] ([**Telephone/Fax (1) [PII]**]) in [**11-23**] [**Known lastna
#          namepattern4 telephone fax 1        attern4) **] ([**Telephone/Fax (1) [PII]**]) in [**1-25**] weeks\nCardiologi
#   namepattern1 last name namepattern4        1) **] [**Last Name (NamePattern4) [PII]**]\nApproved: WED [**2195-9-16**] 1
#       firstname medical record number       tname **] [**Medical Record Number [PII]**] M  [**2113-2-9**]\n\nCardiology R
#                    a street address 2        ment with\na # [**Street Address(2) [PII]**]. [**Male First Name (un) 923**]
#           appointment telephone fax 1         appointment ([**Telephone/Fax (1) [PII]**]\n-Dr [**First Name8 (NamePattern
#                therapy at location un       atient therapy at [**Location (un) [PII]**] Outpatient Center\n([**2194**]\n-
#                 month telephone fax 1        *] 1 month - ([**Telephone/Fax (1) [PII]**] f\n-Infectious Disease in follow
#               intubation date range 3    dure:\nintubation [**Date range (3) [PII]**]\n\n\nHistory of Present Illness:\nM
#                         148 abg was 7       ctate, neg\ntrop, Na 148. ABG was 7.[PII]/43. CXR showed right-sided\natalect
#                 post extubation was 7       , RR 18. ABG\npost-extubation was 7.[PII]/40, so RR was increased. She\nrecei
#                intubated date range 3        nd was intubated [**Date range (3) [PII]**] for hypercarbic respiratory\nfai
#                     days date range 1         40 mg x 5 days ([**Date range (1) [PII]**]). She was\nnoted to be alert and
#                      uti date range 3     e for yeast UTI ([**Date range (3) [PII]**])\n\n\nDischarge Disposition:\nExten
#  name namepattern1 numeric identifier       ttern1) **] #[**Numeric Identifier [PII]**] @1449,\n[**2117-5-19**].\n      C
#   namepattern4 last name namepattern4       4) **] [**Last Name (NamePattern4) [PII]**], MD [**MD Number(2) 65951**]\n\nD
#                        md md number 2       ern4) 27992**], MD [**MD Number(2) [PII]**]\n\nDictated By:[**Last Name (Name
#                    hospital unit name        t 2pm in the\n[**Hospital Unit Name [PII]**] [**Last Name (NamePattern1) **]
#            illness mrs known lastname        T ILLNESS:  Mrs. [**Known lastname [PII]**] is a 82 year-old\nwoman who has
#                        nrb with abg 7        79 R 35 sats 96%\non NRB with ABG 7.[PII]. She was intubated in ED for effor
#                            with abg 7        ced on AC 14/350/5/100%\nwith ABG 7.[PII]. Patient was given Solumedrol 125m
#                                   350       80  P:112  R:27 O2: 100% on AC\n350/[PII]% FIO2\nGeneral: intubated and sedat
#                      last name titles         ame 94236**] [**Last Name (Titles) [PII]**] massive intracerebral bleed on
#                  call telephone fax 1     out this call [**Telephone/Fax (1) [PII]**]\n\n\n\nCompleted by:[**2194-12-15**
#            892 last name namepattern1        892**] [**Last Name (NamePattern1) [PII]**], with pathology\nshowing adenoca
#             lastname last name titles         lastname **] [**Last Name (Titles) [PII]**]d well. He received 10 treatment
#           regarding mr known lastname        ve\nregarding Mr. [**Known lastname [PII]**] care or if he develops new onse
#           discharge mr known lastname        f\ndischarge, Mr. [**Known lastname [PII]**] pain was well controlled on Fen
#    thrombocytopenia mr known lastname         mbocytopenia: Mr [**Known lastname [PII]**] [**Last Name (Titles) **] dropp
#                    nurse last name un         advice of nurse [**Last Name (un) [PII]**]\nwho is monitoring his IFA-Accut
#           regarding mr known lastname        ve\nregarding Mr. [**Known lastname [PII]**] care or if he develops new onse
#                   ck street address 2        0.24\nwith CK [**Street Address(2) [PII]**], Twave changes on EKG. He\nrequi
#          transferred to the hospital6         as transferred to the [**Hospital6 [PII]**].  She was ruled out for myocard
#                   to street address 2         le for 0.5 to [**Street Address(2) [PII]**] depressions inferiorly in V4 th
#             by last name namepattern4         ned by [**Last Name (NamePattern4) [PII]**] [**Last Name (NamePattern1) 151
#                 rehab telephone fax 1       ge from rehab [**Telephone/Fax (1) [PII]**].\n\nNeurologist Dr [**Last Name (
#        known firstname known lastname        wn firstname **] [**Known lastname [PII]**] is a now 9 day old former 38\nwe
#                          is a name ni         mothorax. Mother is a [**Name (NI) [PII]**], para 1, with an EDC of [**2147
#                     scheduled name ni        r underwent\nscheduled [**Name (NI) [PII]**] at [**Hospital **] Hospital giv
#                      tdr month year 2        icult.  Per tDr. [**Month/Year (2) [PII]**], the\npt has been doing well at
#                         neuro name ni        l dp/pt pulses\nNeuro: [**Name (NI) [PII]**], pt awake, tracks examiner, abl
#                      and repeat abg 7        300 P 10 FiO2 80% and repeat ABG 7.[PII]. Noted by\nRT that regular suction
#             history of known lastname         with history of [**Known lastname [PII]**] disease\ns/p aortic valve replac
#                     from month year 2       gurgitation from [**Month/Year (2) [PII]**] heart disease\n.\nCardiac Risk Fa
#        was transferred from hospital3          was transferred from [**Hospital3 [PII]**] on [**5-29**] for further manag
#                when mr known lastname        alitis: When Mr. [**Known lastname [PII]**] presented, his\nconstellation of
#              course mr known lastname         ital course, Mr. [**Known lastname [PII]**] began developing severe frontal
#            embolism mr known lastname        ry embolism: Mr. [**Known lastname [PII]**] began complaining of right\nuppe
#              urgently in the hospital        up non-urgently in the [**Hospital [PII]**] clinic. The symptom\nresolved wi
#                days mr known lastname         y five days, Mr. [**Known lastname [PII]**] [**Last Name (Titles) 28316**]
#                          at the state          (STitle) 68414**] at the [**State [PII]**] for this, at his headache treat
#                   physician name9 pre        ery, if a\nphysician [**Name9 (PRE) [PII]**] these medications to you please
#                      but last name lf         d, lethargic but [**Last Name (LF) [PII]**], [**First Name3 (LF) **] follow
#                provider name10 nameis        ions:\nProvider: [**Name10 (NameIs) [PII]**] [**Last Name (NamePattern4) 133
#                last name namepattern4         368**] [**Last Name (NamePattern4) [PII]**], MD Phone:[**Telephone/Fax (1)
#             hospital1 18 for hospital      [**Hospital1 18**] for [**Hospital [PII]**] medical management.\n\n\nPast Medi
#            name8 namepattern2 name ni         e8 (NamePattern2) **] [**Name (NI) [PII]**] HCP).  Patient was given 2 Unit
#              baby girl known lastname        TORY:  Baby Girl [**Known lastname [PII]**] is triplet number two of three\n
#         name namepattern1 location un        amePattern1) **], [**Location (un) [PII]**],\n[**State 350**], telephone num
#            unit no numeric identifier           Unit No:  [**Numeric Identifier [PII]**]\nAdmission Date: [**2155-2-25**]
#                performed last name un        avage performed, [**Last Name (un) [PII]**] after 250cc. GI was\nconsulted t
#        right nephrectomy at hospital1          right nephrectomy at [**Hospital1 [PII]**]. Pathology noted a 3-cm clear c
#                    again date range 1        -6-23**] & again [**Date range (1) [PII]**].\n- [**Date range (1) 14706**] S
#               husband telephone fax 1     **], husband, [**Telephone/Fax (1) [PII]**].\n\n\nMedications on Admission:\nMe
#                dear ms known lastname      ctions:\nDear Ms. [**Known lastname [PII]**],\n\nIt was pleasure taking care o
#                name ni known lastname        [**Name (NI) **] [**Known lastname [PII]**], triple number\none, was born at
#                       or last name un        reast feeding or [**Last Name (un) [PII]**] 20,\ntaking approximately 73 ccs
#                    or telephone fax 1        st feeding or [**Telephone/Fax (1) [PII]**] 20 every three\nhours.  If mothe
#                breast feeding name ni        er is breast feeding, [**Name (NI) [PII]**] 20 after breast\nfeeding until h
#               which mr known lastname        r day, which Mr. [**Known lastname [PII]**]\nwould remain on until his follo
#                        1 abg showed 7        oxacin 750 mg IV x 1. ABG showed 7.[PII]/27. She\nwas admitted to Medicine o
#               name stitle name stitle         Name (STitle) **] [**Name (STitle) [PII]**] was scheduled for [**3-30**]. R
#                      street address 1      re\n\nFacility:\n[**Street Address(1) [PII]**] Nursing & Rehab Center - [**Loc
#                     name last name lf        tructions:\nName: [**Last Name (LF) [PII]**],[**First Name7 (NamePattern1) *
#              address street address 2        **]\nAddress: [**Street Address(2) [PII]**]., [**Location (un) 8985**], MA\n
#                         d md number 2       n1) 8507**], M.D.  [**MD Number(2) [PII]**]\n\nDictated By:[**Last Name (Name
#              12 07 numeric identifier      5-12**]   07-[**Numeric Identifier [PII]**]   PERITONEAL WASHINGS\n\n\nREPORT
#            803 last name namepattern1        803**] [**Last Name (NamePattern1) [PII]**], CT(ASCP)\n[**First Name11 (Name
#              12 07 numeric identifier      5-12**]   07-[**Numeric Identifier [PII]**]   PERITONEAL WASHINGS\n\n\nREPORT
#            803 last name namepattern1        803**] [**Last Name (NamePattern1) [PII]**], CT(ASCP)\n[**First Name11 (Name
#                  by pcp name10 nameis         ollowed by PCP. [**Name10 (NameIs) [PII]**] check 1 week after dc with PCP
#                      was last name un         ovarian cyst was [**Last Name (un) [PII]**] on pathology and cytology of as
#                last name namepattern4        b Work\n[**Last Name (NamePattern4) [PII]**] in 1week -- results to be check
#                   437 telephone fax 1      1) 437**] -  ([**Telephone/Fax (1) [PII]**] --- [**2169-7-3**] at 11AM\n\n\n\n
#             etiology last name titles        us etiology, [**Last Name (Titles) [PII]**] cerebritis,\nstroke secondary to
#                    a last name titles        ntation of a [**Last Name (Titles) [PII]**] flare, and her\nbehavior did not
#                   of last name titles        scription of [**Last Name (Titles) [PII]**]\ncerebritis and her C3 and C4 le
#                   employed at company    ETOH, IVDA\nemployed at [**Company [PII]**]\n5 children\n\n\nFamily History:\nno
#                 time mr name13 stitle        this time), Mr. [**Name13 (STitle) [PII]**] presented to an\nOSH ([**Hospita
#                         osh hospital3         presented to an\nOSH ([**Hospital3 [PII]**]) in late Decemeber [**2163**] w
#                resides at location un         atient resides at [**Location (un) [PII]**] [**Hospital3 **].  He previousl
#            guided biopsy at hospital6         d IR guided biopsy at [**Hospital6 [PII]**]. We consulted Oncology, GI, and
#              address street address 2         CHC\nAddress: [**Street Address(2) [PII]**], [**Location (un) **],[**Numeri
#                                    of        t (tape unavailable for review)\nof [PII], there is an increase in the gradi
#                         to dr name ni       ts to be\ncalled to Dr.[**Name (NI) [PII]**] office.\nDisp:*90 Tablet(s)* Ref
#               immediately after was 7        ssure. ABG immediately after was 7.[PII]/16 w/lactate\n7.2. He was transferr
#               is a university college        se.  He is a [**University/College [PII]**]trained\northopaedic surgeon.  He
#                  his daughter name ni        roxy is his daughter ([**Name (NI) [PII]**] [**Known lastname 46599**],\nRN)
#             patient dr known lastname        he patient.  Dr. [**Known lastname [PII]**] stated that he\nhad not had a dr
#                  his advocate name ni        hter is\nhis advocate ([**Name (NI) [PII]**] [**Name (NI) 46599**]); althoug
#                               name ni         [**Name (NI) 36211**] [**Name (NI) [PII]**]); although, he lives with his w
#                         d md number 2       n1) 8507**], M.D.  [**MD Number(2) [PII]**]\n\nDictated By:[**Last Name (Name
#                  summary date range 3       \nINTERIM SUMMARY [**Date range (3) [PII]**] - HISTORY:  This delightful\nfir
#                   by last name stitle     \nDictated By:[**Last Name (STitle) [PII]**]\nMEDQUIST36\n\nD:  [**2129-10-27**
#               e medical record number       ame **] E [**Medical Record Number [PII]**] M  73  [**2069-12-16**]\n\nRadiol
# ...
#           to first name8 namepattern2         E TO [**First Name8 (NamePattern2) [PII]**] [**Last Name (NamePattern1) 211
#        stitle 9328 numeric identifier       le) 9328**] #[**Numeric Identifier [PII]**].\n\n
#                     lf first name3 lf         Name (LF) **],[**First Name3 (LF) [PII]**] M. MD\nLocation: [**Doctor Last
#          respiratory problems name ni         espiratory problems.  [**Name (NI) [PII]**], she did start to have LE edema
#             appt at hospital hospital         ppt at [**Hospital **] [**Hospital [PII]**] Health center with [**First Nam
#                    pm telephone fax 1                                 2**] at 3 pm. [**Telephone/Fax (1) [PII]**]\n\n\n\n
#                call doctor first name       \n\nPlease call [**Doctor First Name [PII]**] [**Doctor Last Name **] at 617-
#           and page numeric identifier        GE and page #[**Numeric Identifier [PII]**] to\nschedule a follow up with Nu
#                        blood gas to 7      cant\nimprovement in blood gas to 7.[PII]/27 @ 30% FiO2.\n\nDuring her ICU cou
#             illness mr known lastname        T ILLNESS:   Mr. [**Known lastname [PII]**] is a 37-year-old\ngentleman with
#                 ago mr known lastname        al days ago, Mr. [**Known lastname [PII]**]\nbegan to experience left-sided
#             disease mr known lastname        ry disease.  Mr. [**Known lastname [PII]**] was subsequently\ntransferred to
#              course mr known lastname         TAL COURSE:  Mr. [**Known lastname [PII]**] was taken to the operating room
#                 and mr known lastname        ication, and Mr. [**Known lastname [PII]**] was subsequently\ntransferred to
#                 and mr known lastname         odarone, and Mr. [**Known lastname [PII]**] was subsequently started on ora
#                  11 mr known lastname         133-8-11**], Mr. [**Known lastname [PII]**] was felt stable for discharge h
#              status mr known lastname       RGE STATUS:  Mr. [**Known lastname [PII]**] is to be discharged home.\n\nFOLL
#                  up mr known lastname        \nFOLLOW UP:  Mr. [**Known lastname [PII]**] should follow up with Dr. [**La
#                  by doctor first name    \n\nDictated By:[**Doctor First Name [PII]**]\nMEDQUIST36\n\nD:  [**2133-8-11**]
#                    faces last name un        ysmorphic faces. [**Last Name (un) [PII]**]\nintact. Neck and mouth normal.
#                           3l ns abg 7         received additional 3L NS.  ABG 7.[PII] with\nlactate 0.8.  She continued t
#                   1 month at location        malaise) x 1 month. At [**Location [PII]**]\n(97.2     105     16     110/64
#                       cocci abg 7 296        robic + for Gram+ cocci, ABG 7.296/[PII].1 and base\nexcess ??????12.    Rec
#             brought from the hospital        s\nwas brought from the [**Hospital [PII]**] hospital ED to the [**Hospital1
#               pain mrs known lastname        ft arm pain. Mrs [**Known lastname [PII]**]\ndid not complain of nausea or d
#               at hospital 18 hospital      , at [**Hospital 18**] [**Hospital [PII]**] clinic.\n\n\nPlease follow up with
#    of initials namepattern4 hospital1      ls (NamePattern4) **] [**Hospital1 [PII]**] father and a Haitian mother.\n\n\n
#      attending last name namepattern1       ending:[**Last Name (NamePattern1) [PII]**]\nChief Complaint:\npericardial ef
#              married works at company        tory:\nMarried. Works at [**Company [PII]**]. Immigrated from the Phillipine
#         report c10 numeric identifier       y report C10-[**Numeric Identifier [PII]**].\n.\n[**2106-6-29**] Cytology Per
#              recent travel to country        t ppd. Recent travel to [**Country [PII]**].\nShe was admitted to private ro
#                  2031 telephone fax 1         itle) 2031**] [**Telephone/Fax (1) [PII]**] shows mild ischemia LV RCA dist
#                  2031 telephone fax 1        itle) 2031**] [**Telephone/Fax (1) [PII]**] Tues [**2-7**] at 2:00pm\nPlasti
#                          artery s d m      ed} 53/22\nPULMONARY ARTERY {s/d/m} [PII]\nPULMONARY WEDGE {a/v/m} -/40/27\nLE
#                  in mr known lastname         mprovment in Mr. [**Known lastname [PII]**] EF and MR. [**Name13 (STitle) *
#                  to mr known lastname          H pylori to Mr. [**Known lastname [PII]**] PCP at [**Name Initial (PRE) **
#        complicating mr known lastname        Complicating Mr. [**Known lastname [PII]**] admission was\nrespiratory distr
#               given mr known lastname        nsion: Given Mr. [**Known lastname [PII]**] chronic, rather\ndisconcerting,
#             ornac apartment address 1         131 ORNAC, [**Apartment Address(1) [PII]**], [**Location (un) **],[**Numeri
#                   home in location un        ut of her home in [**Location (un) [PII]**], MA. She is close\nwith her sist
#                 18 hospital ward name         pital1 18**] [**Hospital Ward Name [PII]**] (across from the emergency depa
#                 18 hospital ward name         pital1 18**] [**Hospital Ward Name [PII]**] (across from the emergency depa
#                    time of transfer 7        on CXR. ABG at time of transfer: 7.[PII]. Given lasix 20IV\nx2, transferred
#                  691 last name titles       tles) 691**] [**Last Name (Titles) [PII]**]s.\n\nPlease take all medications
#                  and street address 2       \nBros Way and [**Street Address(2) [PII]**], [**Location **].  Phone:\n[**Te
#                            dr name ni      wup Instructions:\nDr. [**Name (NI) [PII]**]\n[**2185-11-15**] at 1:10pm\n[**H
#                      a friend name ni         Lives with a friend, [**Name (NI) [PII]**].  [**Name2 (NI) **] alcohol or\n
#       namepattern2 122 known lastname        Pattern2) 122**] [**Known lastname [PII]**], [**Telephone/Fax (1) 28266**]\n
#                     initial abg was 7       line\nnot known). Initial ABG was 7.[PII]. WBC was increased to\n15.0. On wea
#                 for mr known lastname        r causes for Mr. [**Known lastname [PII]**] increased oxygen\nreqirement, pu
#                      vanco level 15 7        line ), HCO3 34, vanco level 15, 7.[PII] (last\nintubated gas on [**2-23**])
#           originally from location un        b\nOriginally from [**Location (un) [PII]**], She currently lives with her 2
#                  chem s serial number        IED\n      CHEM S# [**Serial Number [PII]**]D-UCU ADDED [**2192-2-22**] UCU
#                 firstname age over 90       Known firstname **] [**Age over 90 [PII]**] F  66  [**2125-8-2**]\n\nPulmonar
#                stitle 833 name stitle        e (STitle) 833**] [**Name (STitle) [PII]**]\n[**2192-2-26**] 06:25AM BLOOD H
#                stitle 833 name stitle       e (STitle) 833**] [**Name (STitle) [PII]**]\nEllipto-OCCASIONAL\n[**2192-3-10
#               97 5 numeric identifier        s were 97.5  [**Numeric Identifier [PII]**]  110\n 20  90%1L (with typical r
#          replacement street address 2          replacement( [**Street Address(2) [PII]**]. [**Male First Name (un) 923**]
#                  had been at hospital         is testing had been at [**Hospital [PII]**], but he has recently switched h
#                hospital1 date range 1       [**Hospital1 **] [**Date range (1) [PII]**]; then\n200 mg daily ongoing.\nDis
#                  1411 telephone fax 1         (un) 1411**] ([**Telephone/Fax (1) [PII]**].  INR to be drawn on [**5-23**]
#                  1411 telephone fax 1        (un) 1411**] ([**Telephone/Fax (1) [PII]**].  INR to be drawn\non [**5-23**]
#                           of 10 was 7        BG on pressure support of 10 was 7.[PII] on FiO2 of 45%. She\nhad a CT chest
#                        now in name ni        th her husband\nnow in [**Name (NI) [PII]**]. She has 11 years of education.
#                       from dr name ni          which nurse from Dr. [**Name (NI) [PII]**] office confirmed will be taken
#                 who mr known lastname        805**], who Mr. [**Known lastname [PII]**] saw "a few months ago."\n.\nrecen
#                       this time was 7       ternal\nrub. ABG at this time was 7.[PII] on 4L NC. Found to be\nhyperkalemic
#                  2860 telephone fax 1        pany 2860**] ([**Telephone/Fax (1) [PII]**].\nWas getting radiation for post
#                        ni 335 name ni         : [**Name (NI) 335**] [**Name (NI) [PII]**] (wife) [**Telephone/Fax (3) 686
#                  wife telephone fax 3    645**] (wife) [**Telephone/Fax (3) [PII]**]\n\nCode Status: DNR/DNI.\n\n\nMedica
#                       the son name ni        lar symptoms. The son [**Name (NI) [PII]**]'t\nthink the patient had had any
#                   but born in country        Country **] but born in [**Country [PII]**].  Used to\nwork for the Ministry
#                    b6 d3 minerals 250       alcium-mag-vit\nB6-D3-minerals) 250-[PII] mg-mg-mg-unit Oral Daily\n21. tolna
#                      repeat abg was 7       bs times three. A\nrepeat ABG was 7.[PII]. She was admitted to the MICU for\n
#           attending doctor first name   gs\n\nAttending:[**Doctor First Name [PII]**]\nChief Complaint:\nSeizure\n\nMajor
#             first name known lastname         First Name **]) [**Known lastname [PII]**] birth weight was 2400 grams\n(75
#           assistant doctor first name         *] assistant, [**Doctor First Name [PII]**], at [**Telephone/Fax (1) 1237**
#            198 last name namepattern4        198**] [**Last Name (NamePattern4) [PII]**], MD (Primary Care Physician)\nPh
#            un 1468 numeric identifier        un) 1468**], [**Numeric Identifier [PII]**]\nTel:  [**Telephone/Fax (3) 8948
#                   tel telephone fax 3       1562**]\nTel:  [**Telephone/Fax (3) [PII]**]\nNephrologist: Dr. [**First Name
#                children live in state        **]; her children live in [**State [PII]**] and\n[**State **]. Grandchildren
#                 count telephone fax 3        latelet Count [**Telephone/Fax (3) [PII]**] K/uL\n  PERFORMED AT WEST STAT L
#           evaluated mr known lastname        py evaluated Mr. [**Known lastname [PII]**], and felt it was safe to\nfeed h
#                       ni 4457 name ni         [**Name (NI) 4457**] [**Name (NI) [PII]**] (daughter):\n[**Telephone/Fax (1
#               care center of location     y:\nLife Care Center of [**Location [PII]**]\n\nDischarge Diagnosis:\nampullary
#                        anemia name ni        swelling.\n\n#. ANEMIA/[**Name (NI) [PII]**] pt has a history of hemorrhoids
#                  new pcp at hospital3         ion of her new PCP at [**Hospital3 [PII]**].  That can be done through [**H
#              name stitle at hospital3          Name (STitle) **] at [**Hospital3 [PII]**].  We have impressed upon her th
#                   new pcp at hospital      ment of her new PCP at [**Hospital [PII]**].\n\nMedications on Admission:\nunk
#                  for you at hospital3         been made for you at [**Hospital3 [PII]**] in [**Location 16080**].\nDOCTOR
#                           in location        *Hospital3 89729**] in [**Location [PII]**].\nDOCTOR: [**Name6 (MD) 1730**]
#         with first name8 namepattern2         with [**First Name8 (NamePattern2) [PII]**] [**Last Name (NamePattern1) 396
#             systems mr known lastname        F SYSTEMS:   Mr. [**Known lastname [PII]**] notes eating raw oysters\napprox
#             history mr known lastname         AL HISTORY:  Mr. [**Known lastname [PII]**] is married and has two children
#                   normal last name lf         DINATION: Normal [**Last Name (LF) [PII]**], [**First Name3 (LF) **], HTS.
#         first name numeric identifier        rst Name **] [**Numeric Identifier [PII]**] (tyrosine kinase inhibitor)\n-[*
#                    un telephone fax 1      ion (un) **]. [**Telephone/Fax (1) [PII]**]\n\n\n
#               patient telephone fax 1        ion: Patient, [**Telephone/Fax (1) [PII]**] daughter/HCP([**Name (NI) **]\n[
#            admission to the hospital3          for admission to the [**Hospital3 [PII]**] after an electrocardiogram demo
#           and weakness from hospital3         gue and weakness from [**Hospital3 [PII]**] and proceeded directly to cardi
#                 vecuronium abg here 7       alyzed\nwith vecuronium. ABG here 7.[PII]. Vent settings on transfer\nwere AC
#                          status abg 7      ng of altered mental\nstatus. ABG 7.[PII] on AC 500/12/70%/5.\n\nIn our ED, VS
#       blood probnp numeric identifier       BLOOD proBNP-[**Numeric Identifier [PII]**]*\n\n[**2142-7-26**] 06:34AM BLOOD
#                   401 telephone fax 1         (NI) 401**] ([**Telephone/Fax (1) [PII]**]) and son [**Name (NI) 4648**]\n(
#                          last name lf        nd has full time\n[**Last Name (LF) [PII]**], [**First Name3 (LF) **], who p
#                         blood gases 7        in of 1.1.  Arterial\nblood gases 7.[PII], lactate 3.1.  CT of the head show
#                         the hospital6       as brought in the\nthe [**Hospital6 [PII]**] by ambulance after his\ndaughter
#          incontinent at the hospital3       d\nincontinent. At the [**Hospital3 [PII]**] he was found to be febrile\nto 1
#           lf pager numeric identifier        F) **] PAGER [**Numeric Identifier [PII]**] [**2188-10-19**].\n         Pipe
#             26 last name namepattern1          26**] [**Last Name (NamePattern1) [PII]**] -ICU- @ 12:45 [**2188-10-18**].
#              images done at hospital3        spital images done at [**Hospital3 [PII]**] have\nbeen uploaded to the [**Ho
#         is transferred from hospital3        o is transferred from [**Hospital3 [PII]**] for a Zone 2 neck\ninjury that o
#                   of relative name ni        t segment of relative [**Name (NI) [PII]**] along the mid left\nposterior ti
#         performed that demonstrated 7    \nwas performed that demonstrated 7.[PII].\n.\n\nPast Medical History:\n- MDS wi
#                  1911 telephone fax 1       tle) 1911**] ([**Telephone/Fax (1) [PII]**] in [**Location (un) **].\n\nProvi
#           by first name9 namepattern2         k by [**First Name9 (NamePattern2) [PII]**] [**Last Name (un) 6977**] @ 181
#                home ms known lastname         le at home.  Ms. [**Known lastname [PII]**] went to [**Hospital **] hospita
#       stabilization ms known lastname         bilization.  Ms. [**Known lastname [PII]**] [**Last Name (Titles) 9043**] u
#               titles name initial pre        (Titles) **] [**Name Initial (PRE) [PII]**].\nPlease make this appointment b
#              infarction was hospital1        ardial\ninfarction was [**Hospital1 [PII]**] out based EKG and biomarkers. T
#                     pcp and name9 pre       bactrim for PCP and [**Name9 (PRE) [PII]**] prophylaxis.\n\nAccording to her
#                    sears last name un         Worked at\nSears [**Last Name (un) [PII]**] as a firefighter for 41 years,
#             place apartment address 1        **] Place, [**Apartment Address(1) [PII]**]\n([**Telephone/Fax (1) 5455**] e
#           5455 ext numeric identifier         5455**] ext:[**Numeric Identifier [PII]**]\nPager: [**Pager number 40193**]
#                    pager pager number      er 40192**]\nPager: [**Pager number [PII]**]\n[**University/College 40194**]\n
#                    university college      ber 40193**]\n[**University/College [PII]**]\n.\nPlease follow up with other a
#             place apartment address 1        **] Place, [**Apartment Address(1) [PII]**]\n([**Telephone/Fax (1) 5455**] e
#           5455 ext numeric identifier         5455**] ext:[**Numeric Identifier [PII]**]\nPager: [**Pager number 40193**]
#                    pager pager number      er 40192**]\nPager: [**Pager number [PII]**]\n[**University/College 40194**]\n
#                    university college     ber 40193**]\n[**University/College [PII]**]\n\n\n\nCompleted by:[**2123-1-1**]
#          immunoglobulins last name un        immunoglobulins, [**Last Name (un) [PII]**], ferritin,\niron, TIBC suggested

# %% [markdown]
# ## **16a. Comparative Evaluation: DBSCAN vs. K-Means**
# Assess internal validity (Silhouette, DBI) for both algorithms.

# %%
# === side-by-side scores & heatmaps (DBSCAN vs KMeans) ===
def _metrics(X, labels, drop_noise=True):
    """Return (silhouette, dbi). If drop_noise and DBSCAN noise (-1) exists, exclude it."""
    if drop_noise and (-1 in labels):
        m = labels != -1
        if m.sum() < 2 or len(np.unique(labels[m])) < 2:
            return np.nan, np.nan
        return silhouette_score(X[m], labels[m]), davies_bouldin_score(X[m], labels[m])
    if len(np.unique(labels)) < 2:
        return np.nan, np.nan
    return silhouette_score(X, labels), davies_bouldin_score(X, labels)

    # ---- DBSCAN: Grid style
try:
    sil_dbscan, dbi_dbscan, labels_db = sil, dbi, labels
except NameError:
    eps_grid_seed = [0.5, 0.7, 0.9]
    best = (np.nan, np.inf, None, None)
    for eps in eps_grid_seed:
        lab = DBSCAN(eps=eps, min_samples=5, metric="euclidean").fit_predict(X)
        s, d = _metrics(X, lab, drop_noise=True)
        if (np.nan_to_num(s, nan=-1) > np.nan_to_num(best[0], nan=-1)) or \
           (np.isfinite(s) and np.isclose(s, best[0]) and np.nan_to_num(d, nan=np.inf) < np.nan_to_num(best[1], nan=np.inf)):
            best = (s, d, lab, eps)
    sil_dbscan, dbi_dbscan, labels_db, best_eps = best

    # ---- KMEANS: evaluate across k and take the silhouette-best k
ks = range(2, 11)
sil_k_list, dbi_k_list = [], []
for k in ks:
    lab = KMeans(n_clusters=k, n_init=10, random_state=42).fit_predict(X)
    s, d = _metrics(X, lab, drop_noise=False)
    sil_k_list.append(s); dbi_k_list.append(d)
k_best = ks[int(np.nanargmax(sil_k_list))]
labels_km = KMeans(n_clusters=k_best, n_init=10, random_state=42).fit_predict(X)
sil_km, dbi_km = _metrics(X, labels_km, drop_noise=False)

# %% [markdown]
# ## **16b. Visualization of Clustering Scores**
# Plot bar charts comparing DBSCAN and K-Means performance metrics.

# %%
# ---- Print scores side by side
scores = pd.DataFrame(
    {"Algorithm": ["KMeans", "DBSCAN"],
     "Silhouette": [sil_km, sil_dbscan],
     "Davies–Bouldin": [dbi_km, dbi_dbscan]}
)
print(scores.to_string(index=False, float_format=lambda v: f"{v:.3f}"))

# ---- Bar charts: Silhouette and DBI side by side
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
ax[0].bar(["KMeans", "DBSCAN"], [sil_km, sil_dbscan])
ax[0].set_title("Silhouette (higher is better)"); ax[0].set_ylim(0, max(0.0, np.nanmax([sil_km, sil_dbscan]))*1.2)
for i, v in enumerate([sil_km, sil_dbscan]):
    if not np.isnan(v): ax[0].text(i, v + 0.01, f"{v:.3f}", ha="center")

ax[1].bar(["KMeans", "DBSCAN"], [dbi_km, dbi_dbscan])
ax[1].set_title("Davies–Bouldin (lower is better)"); ax[1].set_ylim(0, max(0.0, np.nanmax([dbi_km, dbi_dbscan]))*1.2)
for i, v in enumerate([dbi_km, dbi_dbscan]):
    if not np.isnan(v): ax[1].text(i, v + 0.01, f"{v:.3f}", ha="center")
fig.tight_layout(); plt.show()
# Out:
# Algorithm  Silhouette  Davies–Bouldin
#    KMeans       0.188           2.963
#    DBSCAN       0.417           1.021

# %% [markdown]
# ## **17a. Heatmaps of Silhouette Scores**
# Display parameter-grid heatmaps (ε/ min_samples for DBSCAN; k for K-Means).

# %%
# ---- Heatmaps: DBSCAN vs KMeans (Silhouette)
eps_grid = np.linspace(0.3, 1.2, 10)
min_samples_grid = [3, 5, 7]
sil_db = np.full((len(min_samples_grid), len(eps_grid)), np.nan)
dbi_db = np.full_like(sil_db, np.nan)
for i, ms in enumerate(min_samples_grid):
    for j, eps in enumerate(eps_grid):
        lab = DBSCAN(eps=eps, min_samples=ms, metric="euclidean").fit_predict(X)
        s, d = _metrics(X, lab, drop_noise=True)
        sil_db[i, j] = s; dbi_db[i, j] = d

ks_grid = np.arange(2, 11)
sil_k_hm, dbi_k_hm = [], []
for k in ks_grid:
    lab = KMeans(n_clusters=k, n_init=10, random_state=42).fit_predict(X)
    s, d = _metrics(X, lab, drop_noise=False)
    sil_k_hm.append(s); dbi_k_hm.append(d)
sil_k_hm = np.array(sil_k_hm)[None, :]
dbi_k_hm = np.array(dbi_k_hm)[None, :]

# Silhouette heatmaps: DBSCAN vs KMeans (side by side)
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
im0 = ax[0].imshow(sil_db, aspect="auto"); fig.colorbar(im0, ax=ax[0], label="Silhouette")
ax[0].set_title("DBSCAN Silhouette"); ax[0].set_xlabel("eps"); ax[0].set_ylabel("min_samples")
ax[0].set_xticks(range(len(eps_grid))); ax[0].set_xticklabels([f"{e:.2f}" for e in eps_grid], rotation=45)
ax[0].set_yticks(range(len(min_samples_grid))); ax[0].set_yticklabels(min_samples_grid)

im1 = ax[1].imshow(sil_k_hm, aspect="auto"); fig.colorbar(im1, ax=ax[1], label="Silhouette")
ax[1].set_title("KMeans Silhouette"); ax[1].set_xlabel("k"); ax[1].set_yticks([0]); ax[1].set_yticklabels(["KMeans"])
ax[1].set_xticks(range(len(ks_grid))); ax[1].set_xticklabels([str(k) for k in ks_grid])
fig.tight_layout(); plt.show()

# %% [markdown]
# ## **17b. Heatmaps of DBI Scores**
# Display parameter-grid heatmaps (ε/ min_samples for DBSCAN; k for K-Means).

# %%
# DBI heatmaps: DBSCAN vs KMeans (side by side)
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
im0 = ax[0].imshow(dbi_db, aspect="auto"); fig.colorbar(im0, ax=ax[0], label="DBI")
ax[0].set_title("DBSCAN DBI"); ax[0].set_xlabel("eps"); ax[0].set_ylabel("min_samples")
ax[0].set_xticks(range(len(eps_grid))); ax[0].set_xticklabels([f"{e:.2f}" for e in eps_grid], rotation=45)
ax[0].set_yticks(range(len(min_samples_grid))); ax[0].set_yticklabels(min_samples_grid)

im1 = ax[1].imshow(dbi_k_hm, aspect="auto"); fig.colorbar(im1, ax=ax[1], label="DBI")
ax[1].set_title("KMeans DBI"); ax[1].set_xlabel("k"); ax[1].set_yticks([0]); ax[1].set_yticklabels(["KMeans"])
ax[1].set_xticks(range(len(ks_grid))); ax[1].set_xticklabels([str(k) for k in ks_grid])
fig.tight_layout(); plt.show()

# %% [markdown]
# ## **18. Hierarchical Clustering (Ward Linkage) Benchmark**
# Add agglomerative baseline and compare quality indices.

# %% [markdown]
# This section applies hierarchical clustering with Ward linkage to the reduced embeddings, computes Silhouette and Davies–Bouldin scores for different cluster counts (k=2–10), and compares results against DBSCAN and KMeans.

# %%
# === Hierarchical (Agglomerative) Clustering: Silhouette & Davies–Bouldin ===
import numpy as np, pandas as pd
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize

# Reuse your embedding X if available; otherwise build a compact fallback from notes_df["TEXT"]
def _ensure_X():
    if "X" in globals():
        return X
    assert "notes_df" in globals() and "TEXT" in notes_df, "Provide notes_df['TEXT'] or define X."
    _X_tfidf = TfidfVectorizer(stop_words="english", max_features=3000).fit_transform(notes_df["TEXT"])
    return normalize(TruncatedSVD(n_components=100, random_state=42).fit_transform(_X_tfidf))

X_h = _ensure_X()

# Reuse your helper if defined; else define a compatible one (no noise in hierarchical clustering)
def _metrics_if_missing(X, labels):
    if len(np.unique(labels)) < 2:
        return np.nan, np.nan
    return silhouette_score(X, labels), davies_bouldin_score(X, labels)

if "_metrics" in globals():
    _mx = _metrics
else:
    _mx = lambda X, lab, drop_noise=False: _metrics_if_missing(X, lab)

# Evaluate AgglomerativeClustering over k=2..10 and select the silhouette-best k
ks_h = range(2, 11)
sil_h_list, dbi_h_list = [], []
for k in ks_h:
    # Ward linkage requires Euclidean metric and is standard for numeric embeddings
    lab_h = AgglomerativeClustering(n_clusters=k, linkage="ward").fit_predict(X_h)
    s_h, d_h = _mx(X_h, lab_h, drop_noise=False)
    sil_h_list.append(s_h); dbi_h_list.append(d_h)

k_best_h = ks_h[int(np.nanargmax(sil_h_list))]
labels_h = AgglomerativeClustering(n_clusters=k_best_h, linkage="ward").fit_predict(X_h)
sil_h, dbi_h = _mx(X_h, labels_h, drop_noise=False)

# Assemble comparison table (include KMeans/DBSCAN if available)
rows = [{"Algorithm": "Hierarchical (Ward)", "k/eps": k_best_h, "Silhouette": sil_h, "Davies–Bouldin": dbi_h}]
if "sil_km" in globals() and "dbi_km" in globals():
    rows.append({"Algorithm": "KMeans", "k/eps": "k*",
                 "Silhouette": sil_km, "Davies–Bouldin": dbi_km})
if "sil_dbscan" in globals() and "dbi_dbscan" in globals():
    rows.append({"Algorithm": "DBSCAN", "k/eps": globals().get("best_eps", "eps*"),
                 "Silhouette": sil_dbscan, "Davies–Bouldin": dbi_dbscan})

comp_h = pd.DataFrame(rows)[["Algorithm", "k/eps", "Silhouette", "Davies–Bouldin"]]
print(comp_h.to_string(index=False, float_format=lambda v: f"{v:.3f}"))

# Optional: bar charts including Hierarchical
try:
    import matplotlib.pyplot as plt
    algs = comp_h["Algorithm"].tolist()
    sils = comp_h["Silhouette"].tolist()
    dbis = comp_h["Davies–Bouldin"].tolist()

    fig, ax = plt.subplots(1, 2, figsize=(10, 4))
    ax[0].bar(algs, sils)
    ax[0].set_title("Silhouette (higher is better)")
    ax[0].set_ylim(0, max([v for v in sils if np.isfinite(v)] + [0]) * 1.2)
    for i, v in enumerate(sils):
        if np.isfinite(v): ax[0].text(i, v + 0.01, f"{v:.3f}", ha="center")

    ax[1].bar(algs, dbis)
    ax[1].set_title("Davies–Bouldin (lower is better)")
    ax[1].set_ylim(0, max([v for v in dbis if np.isfinite(v)] + [0]) * 1.2)
    for i, v in enumerate(dbis):
        if np.isfinite(v): ax[1].text(i, v + 0.01, f"{v:.3f}", ha="center")

    fig.tight_layout(); plt.show()
except Exception as e:
    print("Plotting skipped:", e)

# Notes:
# - Ward linkage uses Euclidean distances and is appropriate for your SVD+L2-normalized embeddings.
# - If you wish to try cosine distances, use linkage='average' and metric='cosine' in newer scikit-learn versions,
#   e.g., AgglomerativeClustering(n_clusters=k, linkage='average', metric='cosine').
# Out:
#           Algorithm k/eps  Silhouette  Davies–Bouldin
# Hierarchical (Ward)     4       0.204           1.465
#              KMeans    k*       0.188           2.963
#              DBSCAN 0.500       0.417           1.021
